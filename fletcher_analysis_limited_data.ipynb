# %%
import pandas as pd
import pickle
from codecs import getdecoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
import re
import regex
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.stem import LancasterStemmer
from string import punctuation
from gensim.models.phrases import Phrases, Phraser
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
from sklearn.utils.extmath import randomized_svd
from nltk.chunk import ne_chunk
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
import spacy
import seaborn as sns
from gensim import corpora, models, similarities, matutils, models
import pyLDAvis.gensim
from sklearn.pipeline import make_pipeline
from sklearn.metrics import silhouette_score
from sklearn.decomposition import NMF
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import normalize
from sklearn.cluster import SpectralClustering
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.mixture import GaussianMixture

# %matplotlib inline

# %%
nlp = spacy.load('en')

# %%
with open("paragraph_df.pkl", 'rb') as picklefile: 
    df2 = pickle.load(picklefile)

# %%
df2.head()
# Out:
#                date                            location  \
# 1  January 17, 2017  James S. Brady Press Briefing Room
# 2  January 17, 2017  James S. Brady Press Briefing Room
# 3  January 17, 2017  James S. Brady Press Briefing Room
# 4  January 17, 2017  James S. Brady Press Briefing Room
# 5  January 17, 2017  James S. Brady Press Briefing Room
#
#                                            paragraph  \
# 1                 James S. Brady Press Briefing Room
# 2                                     12:15 P.M. EST
# 3  MR. EARNEST:  Good afternoon, everybody.  I do...
# 4                       Q    Thank you.  (Laughter.)
# 5  MR. EARNEST:  But because today marks my last ...
#
#                                                title
# 1  Press Briefing by Press Secretary Josh Earnest...
# 2  Press Briefing by Press Secretary Josh Earnest...
# 3  Press Briefing by Press Secretary Josh Earnest...
# 4  Press Briefing by Press Secretary Josh Earnest...
# 5  Press Briefing by Press Secretary Josh Earnest...

# %%
df2.tail()
# Out:
#                     date location  \
# 123462  January 28, 2009     None
# 123463  January 27, 2009     None
# 123464  January 26, 2009     None
# 123465  January 23, 2009     None
# 123466  January 22, 2009     None
#
#                                                 paragraph  \
# 123462  \n Press Briefing by Press Secretary Robert Gi...
# 123463  \n Press Briefing by Press Secretary Robert Gi...
# 123464  \n  Press Briefing by Press Secretary Robert G...
# 123465  \n  Press Briefing by Press Secretary Robert G...
# 123466  \n Press Briefing by Press Secretary Robert Gi...
#
#                          title
# 123462  Press Briefing 1/28/09
# 123463  Press Briefing 1/27/09
# 123464  Press Briefing 1/26/09
# 123465  Press Briefing 1/23/09
# 123466  Press Briefing 1/22/09

# %%
def flat_splitter(df):
    """
    Splits documents (initially one per row) into one paragraph per row.
    """
    for document in df:
        for paragraph in document['paragraph'].split('\n'):
            yield {'date': document['date'], 'title': document['title'], 'location': document['location'], \
                   'paragraph': paragraph}

# %%
okdata = df2.groupby("date").filter(lambda x: len(x) > 1)

# %%
# some documents didn't split properly into paragraphs so fixing here...
brokendata = df2.groupby("date").filter(lambda x: len(x) == 1)
records = brokendata.to_dict(orient = 'records')

record_dict = flat_splitter(records)
fixeddata = pd.DataFrame(record_dict)

# %%
okdata.shape
# Out:
# (120380, 4)

# %%
fixeddata.shape
# Out:
# (106084, 4)

# %%
df2 = pd.concat([okdata, fixeddata], axis = 0)
df2.shape
# Out:
# (226464, 4)

# %%
df2['dt'] = pd.to_datetime(df2.date)

# %%
# take second four years
df2 = df2[df2.dt >= 'January 21, 2013']

# %%
df2['paragraph'] = df2.paragraph.str.replace('\xa0', '')
df2['paragraph'] = df2.paragraph.str.replace('\n', ' ')

# remove this as scraping wasn't clean on separating location out from body
df2['paragraph'] = df2.paragraph.str.replace('James S. Brady Press Briefing Room', '')

# get rid of times
df2['paragraph'] = df2.paragraph.str.replace(r'[0-9]+\:[0-9]+[ ]*[A,a,P,p][.]*[m, M][.]*[ ]*[A-Z]{2}[T]', '')

# get rid of empty cells
df2 = df2[df2.paragraph != '']
df2 = df2[df2.paragraph != ' ']

# convert all other numbers to a standard number (ex. 99)
# note this removes the word attached to the number (if it exists); possibly find a way later to leave in years
df2['paragraph'] = df2.paragraph.str.replace(r'[0-9]+', '99')

# removing common punctuation (leave in periods and commas)
df2['paragraph'] = df2.paragraph.str.replace(r'[:;\'!?\-@$%#*&+=\"\“’()]', '')

# %%
df2.head()
# Out:
#                date                            location  \
# 3  January 17, 2017  James S. Brady Press Briefing Room
# 4  January 17, 2017  James S. Brady Press Briefing Room
# 5  January 17, 2017  James S. Brady Press Briefing Room
# 6  January 17, 2017  James S. Brady Press Briefing Room
# 7  January 17, 2017  James S. Brady Press Briefing Room
#
#                                            paragraph  \
# 3  MR. EARNEST Good afternoon, everybody. I dont ...
# 4                             Q Thank you. Laughter.
# 5  MR. EARNEST But because today marks my last br...
# 6  As I prepared to stand here at this podium for...
# 7  I had been in D.C. for a grand total of two we...
#
#                                                title         dt
# 3  Press Briefing by Press Secretary Josh Earnest... 2017-01-17
# 4  Press Briefing by Press Secretary Josh Earnest... 2017-01-17
# 5  Press Briefing by Press Secretary Josh Earnest... 2017-01-17
# 6  Press Briefing by Press Secretary Josh Earnest... 2017-01-17
# 7  Press Briefing by Press Secretary Josh Earnest... 2017-01-17

# %%
# dropping observations where documents didn't break properly by paragraph (i.e. those where there are 3 or less paras)
# this is 223 documents 
# note: fix this later
df2 = df2.groupby("date").filter(lambda x: len(x) > 6)

# %%
df2.to_pickle('fixed_df.pkl')

# %%
doc_list = df2.paragraph.tolist()

# %%
len(doc_list)
# Out:
# 121562

# %%
#doc_list[:10]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121562 entries, 3 to 78174
# Data columns (total 5 columns):
# date         121562 non-null object
# location     109549 non-null object
# paragraph    121562 non-null object
# title        121562 non-null object
# dt           121562 non-null datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 5.6+ MB

# %% [markdown]
# ## entity extraction and stemming

# %%
def underscore_entities(documents):
    
    docs = []
    for i in documents:
        docs.append(nlp(i))
    
    uds_entities = []

    for para in docs:

        ent_chars = []
        for i in para.ents:
            ent_chars.append((i.start_char, i.end_char))
        #print(para.ents)
        #print(ent_chars)
        
        new_string = []
        for index, item in enumerate(list(str(para))):
            for i, j in enumerate(ent_chars):
                if j[0] < index < j[1] and item == ' ':
                    item = '_'
            new_string.append(item)

        ns = ''.join(new_string)
        uds_entities.append(ns)
        
    return uds_entities

# %%
def underscore_nouns(documents):
    
    docs = []
    for i in documents:
        docs.append(nlp(i))
        
    noun_entities = []

    for para in docs:

        ent_chars = []
        for i in para.noun_chunks:
            ent_chars.append((i.start_char, i.end_char))
        #print(para.noun_chunks)
        #print(ent_chars)

        new_string = []
        for index, item in enumerate(list(str(para))):
            for i, j in enumerate(ent_chars):
                if j[0] < index < j[1] and item == ' ':
                    item = '_'
            new_string.append(item)

        ns = ''.join(new_string)
        noun_entities.append(ns)
        
    return noun_entities

# note: may need to remove laughter and applause as these are getting added in

# %%
def entities_and_nouns(documents):
    
    docs = []
    for i in documents:
        docs.append(nlp(i))
    
    entities = []

    for para in docs:

        ent_chars_one = []
        for i in para.ents:
            ent_chars_one.append((i.start_char, i.end_char))
            
        ent_chars_two = []
        for i in para.noun_chunks:
            ent_chars_two.append((i.start_char, i.end_char))
        
        ent_chars = ent_chars_one + ent_chars_two
        #print(ent_chars_two)

        new_string = []
        for index, item in enumerate(list(str(para))):
            for i, j in enumerate(ent_chars):
                if j[0] < index < j[1] and item == ' ':
                    item = '_'
            new_string.append(item)

        ns = ''.join(new_string)
        entities.append(ns)
        
    return entities

# %%
def porter_stem(doc):
    stems = []
    for line in doc:
        doc_stems = []
        tokens = word_tokenize(line)
        for item in tokens:
            doc_stems.append(PorterStemmer().stem(item))
        stems.append(' '.join(doc_stems))
    return stems

# %%
def lancaster_stem(doc):
    stems = []
    for line in doc:
        doc_stems = []
        tokens = word_tokenize(line)
        for item in tokens:
            doc_stems.append(LancasterStemmer().stem(item))
        stems.append(' '.join(doc_stems))
    return stems

# %%
def svd_km_plot(vecs):

    U, Sigma, VT = randomized_svd(vecs, n_components = 300, n_iter = 5)

    km = KMeans(n_clusters = 15, random_state = 42)
    km.fit(np.dot(U, np.diag(Sigma)))

    # predict one cluster per document
    predicted_cluster = km.predict(np.dot(U, np.diag(Sigma)))

    df = pd.DataFrame(U[:,0:2], columns = ['first_feat', 'second_feat'])
    df['cluster'] = predicted_cluster

    sns.lmplot(x = 'first_feat', y='second_feat', hue = 'cluster', data = df, fit_reg = False)

# %% [markdown]
# ### create test sets

# %%
test = doc_list[:1000]

# %%
ent_test = underscore_entities(test)

# %%
nouns_test = underscore_nouns(test)

# %%
e_and_n_test = entities_and_nouns(test)

# %% [markdown]
# ### compare stemmers

# %%
cv = CountVectorizer(stop_words = 'english')
vecs = cv.fit_transform(porter_stem(ent_test))
svd_km_plot(vecs)

# %%
cv = CountVectorizer(stop_words = 'english')
vecs = cv.fit_transform(lancaster_stem(ent_test))
svd_km_plot(vecs)

# %%
binary = CountVectorizer(stop_words = 'english', binary = True)
vecs = binary.fit_transform(porter_stem(ent_test))
svd_km_plot(vecs)

# %%
binary = CountVectorizer(stop_words = 'english', binary = True)
vecs = binary.fit_transform(lancaster_stem(ent_test))
svd_km_plot(vecs)

# %%
tfidf = TfidfVectorizer(stop_words = "english")
vecs = tfidf.fit_transform(porter_stem(ent_test))
svd_km_plot(vecs)

# %%
tfidf = TfidfVectorizer(stop_words = "english")
vecs = tfidf.fit_transform(lancaster_stem(ent_test))
svd_km_plot(vecs)

# %% [markdown]
# **will go with lancaster stemmer**

# %% [markdown]
# ### compare entity extraction and vectorizers

# %%
test_list = [ent_test, nouns_test, e_and_n_test]

# %%
for i in test_list:
    cv = CountVectorizer(stop_words = 'english')
    vecs = cv.fit_transform(lancaster_stem(i))
    svd_km_plot(vecs)

# %%
for i in test_list:
    binary = CountVectorizer(stop_words = 'english', binary = True)
    vecs = binary.fit_transform(lancaster_stem(i))
    svd_km_plot(vecs)

# %%
for i in test_list:
    tfidf = TfidfVectorizer(stop_words = "english")
    vecs = tfidf.fit_transform(lancaster_stem(i))
    svd_km_plot(vecs)

# %% [markdown]
# ## set test size

# %%
# currently at 5000

# %%
test = doc_list[:5000]

# %%
# then pick one vector section to run

# %% [markdown]
# ## count vecs

# %% [markdown]
# this does poorly (gives common words in many clusters)

# %%
# stemmed_ents = lancaster_stem(underscore_entities(test))

# %%
# cv = CountVectorizer(stop_words = 'english')
# vecs = cv.fit_transform(stemmed_ents)

# %%
# cv_df = pd.DataFrame(vecs.todense(), columns=cv.get_feature_names())
# cv_df.shape

# %%
# terms = cv.get_feature_names()

# %%
# terms

# %% [markdown]
# ## binary vecs

# %%
# entities_and_nouns gives 19645 features...
# stemmed_ents = lancaster_stem(entities_and_nouns(test))
# stemmed_ents = lancaster_stem(underscore_entities(test))

# %%
# binary = CountVectorizer(stop_words = 'english', binary = True)
# vecs = binary.fit_transform(stemmed_ents)

# %%
# binary_df = pd.DataFrame(vecs.todense(), columns=binary.get_feature_names())
# binary_df.shape

# %%
# terms = binary.get_feature_names()

# %%
# terms

# %% [markdown]
# ##  tfidf vecs

# %% [markdown]
# tfidf and lancaster seem to be the best

# %%
# note test is currently at 5000
stemmed_ents = lancaster_stem(underscore_entities(test))
# full data
# stemmed_ents = lancaster_stem(underscore_entities(doc_list))

# %%
tfidf = TfidfVectorizer(stop_words = "english")
vecs = tfidf.fit_transform(stemmed_ents)

# %%
tfidf_df = pd.DataFrame(vecs.todense(), columns=tfidf.get_feature_names())
tfidf_df.shape
# Out:
# (5000, 6295)

# %%
terms = tfidf.get_feature_names()

# %%
terms
# Out:
# ['99',
#  '9999',
#  '9999_a',
#  '9999_p',
#  '99_99_million',
#  '99__and',
#  '99__fiscal_year_99',
#  '99__im',
#  '99__its',
#  '99_a_year',
#  '99_an_hour',
#  '99_and_99',
#  '99_billion',
#  '99_days',
#  '99_hours',
#  '99_hours_ago',
#  '99_in',
#  '99_in_the_dow',
#  '99_jobs',
#  '99_million',
#  '99_million_barrels',
#  '99_minutes',
#  '99_minutes_interview',
#  '99_months',
#  '99_or',
#  '99_or_99',
#  '99_or_99_years_ago',
#  '99_or_so',
#  '99_perc',
#  '99_percent',
#  '99_proisil',
#  '99_special_operations_forces',
#  '99_square_kilometers',
#  '99_straight_months',
#  '99_subpar_years',
#  '99_to',
#  '99_to_99',
#  '99_trillion',
#  '99_trillion_reduction',
#  '99_world_series_victory',
#  '99_years',
#  '99_years_ago',
#  '99_years_ago_this_week',
#  '99_years_ago_today',
#  '99_years_later',
#  '99_years_or_so',
#  '99character',
#  '99day',
#  '99foot',
#  '99kilometer',
#  '99month',
#  '99nd',
#  '99page',
#  '99plus_million',
#  '99pound',
#  '99s',
#  '99some_odd_years_or_so_ago',
#  '99st',
#  '99st_century',
#  '99th',
#  '_99',
#  '_brady_briefing_room',
#  '_bush',
#  '_but',
#  '_california',
#  '_central_command',
#  '_day',
#  '_eastern',
#  '_edgar_hoover',
#  '_general_assembly',
#  '_hwang',
#  '_ill',
#  '_kennedy',
#  '_navy',
#  '_obama',
#  '_petersburg',
#  '_president',
#  '_president_erdogan',
#  '_presidentelect_trump',
#  '_republican_leader_of_the_united_states_senate',
#  '_security_council',
#  '_security_council_resolution',
#  '_special_operations_command',
#  '_year',
#  'a99',
#  'a_99_percent',
#  'a_couple_days_ago',
#  'a_couple_minutes',
#  'a_couple_months_ago',
#  'a_couple_months_from_now',
#  'a_couple_of_other',
#  'a_couple_of_years',
#  'a_couple_weeks',
#  'a_day',
#  'a_day_later',
#  'a_defense_policy',
#  'a_department_of_homeland_security',
#  'a_few_days',
#  'a_few_days_ago',
#  'a_few_months',
#  'a_few_occasions',
#  'a_few_of_the',
#  'a_few_weeks_ago',
#  'a_few_years_ago',
#  'a_few_years_from_now',
#  'a_few_years_later',
#  'a_larger',
#  'a_lieutenant_general',
#  'a_long_period_of_time',
#  'a_month',
#  'a_month_ago',
#  'a_nobel_prize',
#  'a_republican_congress',
#  'a_season',
#  'a_thousand',
#  'a_u',
#  'a_week',
#  'a_week_ago',
#  'a_week_later',
#  'a_year',
#  'a_year_ago',
#  'a_year_of_growth',
#  'a_year_old',
#  'a_year_to_today',
#  'ab',
#  'abandon',
#  'abc',
#  'abc_news',
#  'abc_newswashington_post',
#  'abd',
#  'abd_albasit_aliraqi',
#  'abes_old',
#  'abet',
#  'abid',
#  'abl',
#  'aboard',
#  'abort',
#  'about_99',
#  'about_99_billion',
#  'about_99_days',
#  'about_99_miles',
#  'about_99_million',
#  'about_99_months_ago',
#  'about_99_perc',
#  'about_99_to_99',
#  'about__more',
#  'about_a_half_dozen',
#  'about_a_month_ago',
#  'about_a_thousand',
#  'about_a_week_ago',
#  'about_a_year',
#  'about_a_year_ago',
#  'about_a_year_later',
#  'about_eight',
#  'about_five_minutes',
#  'about_half',
#  'about_half_a_million',
#  'about_last_week',
#  'about_north_koreas',
#  'about_one',
#  'about_one_month_ago',
#  'about_six_months',
#  'about_six_months_ago',
#  'about_some_type',
#  'about_the_kind',
#  'about_three_days_ago',
#  'about_three_years',
#  'about_two',
#  'about_two_months',
#  'about_two_years_ago',
#  'abov',
#  'abroad',
#  'abs',
#  'absolv',
#  'absorb',
#  'abst',
#  'abstain',
#  'absurd',
#  'abu_bakr_baghdadi',
#  'abu_nabil',
#  'abus',
#  'abyss',
#  'ac',
#  'academ',
#  'acc',
#  'acceiv',
#  'accel',
#  'access',
#  'accid',
#  'acclaim',
#  'accompany',
#  'accompl',
#  'accord',
#  'account',
#  'accounts',
#  'accum',
#  'accus',
#  'achiev',
#  'acknowledg',
#  'aclu',
#  'acquir',
#  'acronym',
#  'act',
#  'activeduty',
#  'acut',
#  'ad',
#  'adam',
#  'adam_szubin',
#  'adapt',
#  'addict',
#  'addit',
#  'address',
#  'adequ',
#  'adh',
#  'adjud',
#  'adjust',
#  'admin',
#  'admir',
#  'admit',
#  'adn',
#  'adopt',
#  'adult',
#  'adv',
#  'advers',
#  'advert',
#  'advoc',
#  'aer',
#  'aetn',
#  'af',
#  'affair',
#  'affect',
#  'affin',
#  'affirm',
#  'afflict',
#  'afford',
#  'affordable_care_act',
#  'affy',
#  'afgh',
#  'afghanistanpak',
#  'afield',
#  'afo',
#  'afr',
#  'afraid',
#  'afric',
#  'african_americ',
#  'african_americans',
#  'aft',
#  'afteract',
#  'afterma',
#  'afternoon',
#  'aftertax',
#  'afterward',
#  'ag',
#  'age_99',
#  'age_99_or_so',
#  'age_of_99',
#  'agend',
#  'agenda',
#  'aggreg',
#  'aggress',
#  'ago',
#  'agr',
#  'agree',
#  'agreedupon',
#  'agricult',
#  'ahead',
#  'ahold',
#  'aid',
#  'aim',
#  'air',
#  'air_force_one',
#  'air_force_one_en_route_chicago',
#  'air_force_one_en_route_tampa',
#  'airbas',
#  'airborn',
#  'aircondit',
#  'aircraft',
#  'airlin',
#  'airpl',
#  'airspac',
#  'airstrik',
#  'aisl',
#  'aixtron',
#  'ak',
#  'al',
#  'al_gore',
#  'al_harvey',
#  'al_jazeera',
#  'al_nusra',
#  'al_qaeda',
#  'alabam',
#  'alarm',
#  'alask',
#  'alassad',
#  'albab',
#  'albaghdad',
#  'aleksey_belan',
#  'aleppo',
#  'aleppo_i',
#  'alert',
#  'alex',
#  'alex_platkin',
#  'alg',
#  'align',
#  'alik',
#  'all_african_american',
#  'all_eight_years',
#  'all_the',
#  'all_week',
#  'allam',
#  'allconsum',
#  'allday',
#  'alleg',
#  'allencompass',
#  'allevy',
#  'allnight',
#  'alloc',
#  'allow',
#  'alltim',
#  'allud',
#  'allvolunt',
#  'almost_99',
#  'almost_99_perc',
#  'almost_99_years',
#  'almost_any_hour',
#  'almost_eight_years',
#  'almost_exactly_eight',
#  'almost_seven_years',
#  'almost_six_years',
#  'almost_two_hours',
#  'alon',
#  'alt',
#  'alterc',
#  'altern',
#  'altitud',
#  'altogeth',
#  'alumin',
#  'alway',
#  'aly',
#  'amano',
#  'amass',
#  'amaz',
#  'amb',
#  'ambassad',
#  'ambassador_powers',
#  'ambassador_rice',
#  'ambigu',
#  'ambit',
#  'amend',
#  'americ',
#  'america',
#  'americangrown',
#  'americanmad',
#  'amid',
#  'ammunit',
#  'ampl',
#  'amy_sands',
#  'an_additional',
#  'an_hour',
#  'analog',
#  'analys',
#  'analysist',
#  'analyst',
#  'anb',
#  'anbar',
#  'anbar_province',
#  'and_lots',
#  'and_the',
#  'andre',
#  'andreas_when',
#  'andrew',
#  'ang',
#  'angela_merkel',
#  'angl',
#  'angry',
#  'angst',
#  'anim',
#  'anit',
#  'ank',
#  'ankar',
#  'annivers',
#  'annount',
#  'ano_po',
#  'anonym',
#  'anoth',
#  'another_99',
#  'another_99_years',
#  'another_month',
#  'another_six_months',
#  'answ',
#  'ant',
#  'antiaircraft',
#  'antiassad',
#  'antibal',
#  'anticip',
#  'antiisil',
#  'antiisrael',
#  'antilgbt',
#  'antimissil',
#  'antipoverty',
#  'antiruss',
#  'antisemit',
#  'antivir',
#  'antoinette_rangel',
#  'anxy',
#  'any_year',
#  'anybody',
#  'anym',
#  'anyon',
#  'anyth',
#  'anytim',
#  'anywh',
#  'ap',
#  'apart',
#  'apec',
#  'apolit',
#  'apolog',
#  'app',
#  'apparat',
#  'appear',
#  'appel',
#  'appetit',
#  'appl',
#  'applaud',
#  'applaus',
#  'application',
#  'apply',
#  'appoint',
#  'apport',
#  'appr',
#  'appra',
#  'apprecy',
#  'approach',
#  'appropry',
#  'approv',
#  'approximately_99_kilometers',
#  'april',
#  'april_99st',
#  'april_99th',
#  'april_of_last_year',
#  'april_say',
#  'apt',
#  'ar',
#  'arab',
#  'arabia',
#  'arabisrael',
#  'arch',
#  'architect',
#  'arct',
#  'ard',
#  'area',
#  'argentin',
#  'argu',
#  'ari_fleischer',
#  'arlington',
#  'arm',
#  'armtw',
#  'army',
#  'armynavy',
#  'aros',
#  'around_99_percent',
#  'arrang',
#  'array',
#  'ars',
#  'art',
#  'artic',
#  'as_long',
#  'as_many',
#  'as_many_of',
#  'as_much_a',
#  'as_much_as_possible',
#  'as_much_as_they',
#  'as_much_as_we_could',
#  'as_short_as_possible',
#  'ascrib',
#  'ash_carter',
#  'asid',
#  'ask',
#  'aspect',
#  'aspir',
#  'ass',
#  'assad',
#  'assang',
#  'assassin',
#  'assault',
#  'assembl',
#  'assert',
#  'assess',
#  'assessment_a_month',
#  'asset',
#  'assidu',
#  'assign',
#  'assist',
#  'assocy',
#  'assu',
#  'assum',
#  'asterisk',
#  'asyl',
#  'at_least',
#  'at_least_99',
#  'at_least_a_calculation',
#  'at_least_a_couple',
#  'at_least_a_generation',
#  'at_least_a_handful',
#  'at_least_a_thre',
#  'at_least_as',
#  'at_least_as_effective',
#  'at_least_four',
#  'at_least_on',
#  'at_least_one',
#  'at_least_three',
#  'at_least_two',
#  'athen',
#  'atl',
#  'atmosph',
#  'atom',
#  'atroc',
#  'atrocities',
#  'attach',
#  'attack',
#  'attempt',
#  'attend',
#  'attest',
#  'attitud',
#  'attorney',
#  'attract',
#  'attribut',
#  'audio',
#  'audiotap',
#  'audy',
#  'aug',
#  'august',
#  'august_99th',
#  'august_of_99_to_august_this_year',
#  'aust',
#  'austral',
#  'auth',
#  'authorit',
#  'auto',
#  'autom',
#  'automak',
#  'automobl',
#  'autonom',
#  'autowork',
#  'av',
#  'avail',
#  'avenu',
#  'avert',
#  'avoid',
#  'avuncul',
#  'avuncular_laught',
#  'aw',
#  'await',
#  'award',
#  'awardwin',
#  'awash',
#  'away',
#  'awesom',
#  'awkward',
#  'ax',
#  'axl',
#  'ayesh',
#  'bab',
#  'backandfor',
#  'backdrop',
#  'background',
#  'backlash',
#  'backlog',
#  'backoftheenvelop',
#  'backtrack',
#  'bad',
#  'bag',
#  'baghdad',
#  'baij',
#  'bail',
#  'baitandswitch',
#  'bal',
#  'balk',
#  'balloon',
#  'ballot',
#  'balt',
#  'baltim',
#  'ban',
#  'band',
#  'bandwid',
#  'bandy',
#  'bank',
#  'bankrupt',
#  'bankruptcy',
#  'bar',
#  'barack',
#  'barack_h',
#  'barack_hussein_obama',
#  'barack_obama',
#  'barb',
#  'bargain',
#  'barney',
#  'barry',
#  'bartend',
#  'bas',
#  'basebal',
#  'baseless',
#  'baselin',
#  'bash',
#  'bashar_alassad',
#  'bashar_alassads',
#  'bast',
#  'bat',
#  'batch',
#  'baton',
#  'battery',
#  'battl',
#  'battlefield',
#  'battleground',
#  'battleready',
#  'bear',
#  'bear_grylls',
#  'beard',
#  'beat',
#  'beauty',
#  'becam',
#  'becaus',
#  'beck_doreystein',
#  'becom',
#  'bed',
#  'bedevil',
#  'bedrock',
#  'bedroom',
#  'beefedup',
#  'bef',
#  'befal',
#  'beg',
#  'begin',
#  'begrudg',
#  'begun',
#  'behalf',
#  'behav',
#  'behavy',
#  'behest',
#  'behindthesc',
#  'bel',
#  'belg',
#  'believ',
#  'belong',
#  'ben',
#  'ben_rhodes',
#  'bench',
#  'benchmark',
#  'benef',
#  'beneficy',
#  'benefit',
#  'benghaz',
#  'ber',
#  'bergdahl',
#  'berlin',
#  'bernie_sanders',
#  'besid',
#  'besieg',
#  'best',
#  'bet',
#  'betray',
#  'between_99',
#  'between_99_and_the',
#  'between_april_and_october_to_allow_the_russians',
#  'between_now_and_january_99th',
#  'between_now_and_january_99th_other_than_to_confirm',
#  'between_now_and_th',
#  'between_now_and_the_end_of_his_administrat',
#  'between_now_and_the_end_of_the_administrat',
#  'between_now_and_wh',
#  'between_our_two_countries',
#  'between_representatives_of_the_united_states_government',
#  'between_the_two_countries',
#  'between_the_two_m',
#  'between_the_two_parties',
#  'between_two',
#  'bewild',
#  'bias',
#  'bic',
#  'bid',
#  'big',
#  'big_agenda',
#  'biggest',
#  'bil',
#  'bill_press',
#  'billboard',
#  'billions_of_dollar',
#  'billions_on_the_project',
#  'bin',
#  'bin_lad',
#  'bind',
#  'bipart',
#  'bir',
#  'birthplac',
#  'bisex',
#  'bit',
#  'bitepack',
#  'black',
#  'blackberry',
#  'blackenergy',
#  'blair_house',
#  'blam',
#  'blanket',
#  'blasphemy',
#  'blast',
#  'bless',
#  'blew',
#  'blind',
#  'blist',
#  'bloc',
#  'block',
#  'blood',
#  'bloodsh',
#  'bloodstream',
#  'bloody',
#  'bloomberg',
#  'blot',
#  'blow',
#  'blu',
#  'blue_ribbon',
#  'bluecoll',
#  'bluff',
#  'blunt',
#  'blust',
#  'bo',
#  'board',
#  'boatlift',
#  'bob',
#  'bob_corker',
#  'bob_dylan',
#  'bod',
#  'body',
#  'boe',
#  'bogachev',
#  'boil',
#  'boko_haram',
#  'bold',
#  'bolst',
#  'bomb',
#  'bon',
#  'bond',
#  'boo',
#  'book',
#  'bookend',
#  'boost',
#  'bord',
#  'born',
#  'borrow',
#  'boss',
#  'bottl',
#  'boubaker_alhakim',
#  'bought',
#  'bound',
#  'box',
#  'boy',
#  'boycot',
#  'brac',
#  'bracket',
#  'bradley_mannings',
#  'brag',
#  'brain',
#  'branch',
#  'brand',
#  'brandi_hoffine',
#  'brav',
#  'brea',
#  'breach',
#  'bread',
#  'break',
#  'breakdown',
#  'breakfast',
#  'breakthrough',
#  'breathtak',
#  'breezy',
#  'bren',
#  'bret',
#  'brett_mcgurk',
#  'brian_gabriel',
#  'brick',
#  'bridg',
#  'brief',
#  'bright',
#  'bring',
#  'brisk',
#  'brit',
#  'britain',
#  'broad',
#  'broadcast',
#  'broadest',
#  'brok',
#  'bronz',
#  'brothers_keeper_alliance',
#  'brought',
#  'brown',
#  'brows',
#  'brunt',
#  'brush',
#  'brussel',
#  'brut',
#  'bubbl',
#  'buck',
#  'bucket',
#  'buddy',
#  'budget',
#  'buff',
#  'buffet',
#  'build',
#  'built',
#  'builtin',
#  'builtup',
#  'bul',
#  'bulk',
#  'bullet',
#  'bum',
#  'bump',
#  'bumpy',
#  'bunch',
#  'bunk',
#  'bur',
#  'burd',
#  'burdensh',
#  'burea',
#  'bureau',
#  'bureaucr',
#  'burgeon',
#  'burn',
#  'burq',
#  'burrow',
#  'burwel',
#  'bury',
#  'bush',
#  'businesslik',
#  'busy',
#  'butb',
#  'button',
#  'buy',
#  'buzzfee',
#  'caa',
#  'cabinet',
#  'cabinetlevel',
#  'cabl',
#  'caitlin_young',
#  'cajol',
#  'cak',
#  'cal',
#  'calc',
#  'calend',
#  'californ',
#  'californiatosouthern_california',
#  'caliph',
#  'calm',
#  'cam',
#  'camaradery',
#  'cambridg',
#  'camer',
#  'camera',
#  'cameron',
#  'camp',
#  'campaign',
#  'canad',
#  'cancel',
#  'cancer_moonshot',
#  'candid',
#  'cannon',
#  'cap',
#  'capac',
#  'capit',
#  'capitol',
#  'capitol_hil',
#  'capt',
#  'car',
#  'carbon',
#  'card',
#  'carerel',
#  'carl_woog',
#  'carn',
#  'carney_laughter',
#  'carol',
#  'carry',
#  'carryov',
#  'cart',
#  'cas',
#  'casebycas',
#  'cash',
#  'cassidy',
#  'cast',
#  'castro',
#  'casual',
#  'catalog',
#  'catalys',
#  'catch',
#  'categ',
#  'cathy_mcmorris_rodgers',
#  'cauc',
#  'caucus',
#  'caught',
#  'caus',
#  'caut',
#  'cauty',
#  'cbo',
#  'cdc',
#  'cea',
#  'ceas',
#  'ceasefir',
#  'ced',
#  'celebr',
#  'celebrity_apprentice',
#  'cellphon',
#  'cem',
#  'cemetery',
#  'cens',
#  'cent',
#  'centcom',
#  'central_america',
#  'central_american',
#  'central_command',
#  'centrifug',
#  'centurieslong',
#  'century_cures_act',
#  'ceo',
#  'ceremony',
#  'cern',
#  'cert',
#  'certain',
#  'certainty',
#  'certitud',
#  'cess',
#  'ceter',
#  'cfi',
#  'chad',
#  'chaffetz',
#  'chain',
#  'chainofcommand',
#  'chair',
#  'chairm',
#  'chaka_fattah',
#  'challeng',
#  'chamb',
#  'champ',
#  'champagn',
#  'chancel',
#  'chancellor_merkel',
#  'chang',
#  'channel',
#  'chant',
#  'chao',
#  'chaot',
#  'chapt',
#  'char',
#  'charact',
#  'charg',
#  'chargescount',
#  'charles_schumer',
#  'charleston',
#  'charlot',
#  'chart',
#  'chat',
#  'che',
#  'cheap',
#  'check',
#  'checkup',
#  'chelsea_manning',
#  'chelsea_mannings',
#  'chem',
#  'cher',
#  'cheryl',
#  'chest',
#  'chew',
#  'chewedov',
#  'chicago',
#  'chief',
#  'child',
#  'childc',
#  'childless',
#  'childr',
#  'chin',
#  'china',
#  'chines',
#  'chip',
#  'chlorine',
#  'cho',
#  'chok',
#  'choos',
#  'choosy',
#  'chop',
#  'choppy',
#  'chos',
#  'chris',
#  'chris_fonzone',
#  'christians',
#  'christmas',
#  'christmas_to',
#  'chronicled',
#  'chronology',
#  'chuck_grassley',
#  'chuck_schumer',
#  'chuckl',
#  'chunk',
#  'church',
#  'cia',
#  ...]

# %%
id2word = dict((v, k) for k, v in tfidf.vocabulary_.items())

# %% [markdown]
# ## LSA (sklearn) + kmeans / dbscan / agglomerative clustering / spectral / gaussian mixture

# %% [markdown]
# **SVD + normalize**

# %%
lsa = TruncatedSVD(300, algorithm = 'arpack')
lsa_vecs = lsa.fit_transform(vecs)
lsa_vecs = Normalizer(copy=False).fit_transform(lsa_vecs)

# %%
# note: this doesn't deal with clusters, just gets the words from lsa...
# component three looks like the economy...

lsa_df = pd.DataFrame(lsa.components_.round(5),columns = tfidf.get_feature_names())

for i in range(20):
    print('Component number: ' + str(i))
    print(lsa_df.iloc[i,:].sort_values(ascending = False)[:15])
    print("")
# Out:
# Component number: 0
# presid     0.24404
# mr         0.24257
# hav        0.23463
# earnest    0.22939
# thi        0.22508
# ar         0.18315
# ther       0.16518
# think      0.15274
# wel        0.13468
# wil        0.13127
# som        0.11859
# wer        0.10836
# going      0.10735
# al         0.10073
# just       0.09668
# Name: 0, dtype: float64
#
# Component number: 1
# earnest      0.63711
# mr           0.60990
# okay         0.12456
# wel          0.08831
# ye           0.08512
# laught       0.07674
# thank        0.06281
# dont         0.05317
# yeah         0.04490
# im           0.04001
# sur          0.03312
# schultz      0.02672
# let          0.02477
# apprecy      0.02331
# everybody    0.02135
# Name: 1, dtype: float64
#
# Component number: 2
# thank        0.84432
# josh         0.29958
# everybody    0.16425
# tomorrow     0.12763
# yo           0.11803
# quest        0.08403
# want         0.07890
# laught       0.07879
# al           0.07412
# kevin        0.07172
# presid       0.05776
# apprecy      0.05359
# press        0.04781
# start        0.04755
# today        0.03961
# Name: 2, dtype: float64
#
# Component number: 3
# presid      0.45536
# wil         0.19063
# obam        0.16238
# country     0.12687
# opportun    0.09473
# end         0.09391
# policy      0.08821
# econom      0.08241
# incom       0.07294
# benefit     0.07069
# hav         0.06904
# hes         0.06797
# work        0.06795
# republ      0.06790
# peopl       0.06583
# Name: 3, dtype: float64
#
# Component number: 4
# ar         0.49021
# ther       0.20129
# going      0.13494
# republ     0.12132
# peopl      0.12020
# thank      0.11682
# end        0.10820
# thos       0.10408
# mor        0.08415
# thes       0.07585
# country    0.07362
# hav        0.07302
# heal       0.07055
# cub        0.06726
# right      0.06578
# Name: 4, dtype: float64
#
# Component number: 5
# end                  0.92303
# intellig             0.11011
# commun               0.10416
# russ                 0.08757
# thank                0.06988
# the_united_states    0.06368
# act                  0.05903
# elect                0.04566
# sec                  0.03697
# malicy               0.03586
# cyb                  0.03529
# nat                  0.03353
# diplom               0.03248
# obam                 0.03037
# try                  0.03019
# Name: 5, dtype: float64
#
# Component number: 6
# end       0.32204
# quest     0.27402
# yo        0.25194
# thi       0.21770
# dont      0.16088
# say       0.15606
# laught    0.14037
# going     0.13808
# know      0.13443
# im        0.13145
# want      0.11447
# hav       0.08695
# lik       0.08152
# tim       0.07322
# look      0.07319
# Name: 6, dtype: float64
#
# Component number: 7
# kevin       0.98188
# hav         0.04234
# dont        0.03854
# think       0.03505
# want        0.03287
# opportun    0.02968
# quest       0.02775
# start       0.02686
# wel         0.02516
# stephany    0.01837
# com         0.01607
# act         0.01574
# thi         0.01563
# apprecy     0.01523
# im          0.01134
# Name: 7, dtype: float64
#
# Component number: 8
# okay      0.57936
# presid    0.20324
# laught    0.20024
# ar        0.15408
# say       0.15106
# going     0.11833
# ther      0.11132
# yo        0.10524
# kevin     0.10499
# russ      0.08092
# did       0.07888
# 99        0.07400
# wer       0.07073
# thi       0.06075
# mor       0.05815
# Name: 8, dtype: float64
#
# Component number: 9
# hav          0.33605
# okay         0.28893
# intellig     0.17947
# laught       0.16179
# commun       0.16004
# dont         0.13652
# think        0.13343
# yo           0.12760
# good         0.12529
# quest        0.10873
# republ       0.09652
# heal         0.07764
# peopl        0.06954
# everybody    0.06564
# democr       0.06367
# Name: 9, dtype: float64
#
# Component number: 10
# ther              0.33237
# ar                0.32992
# presid            0.27302
# im                0.17189
# going             0.15199
# intellig          0.14667
# commun            0.11430
# know              0.10902
# end               0.09968
# the_white_hous    0.08830
# laught            0.08189
# presidentelect    0.07436
# report            0.07353
# brief             0.07340
# dont              0.06546
# Name: 10, dtype: float64
#
# Component number: 11
# okay              0.56848
# wil               0.34780
# hav               0.33395
# ther              0.10754
# report            0.10191
# brief             0.09192
# som               0.08609
# the_white_hous    0.07149
# congress          0.05934
# meet              0.05903
# thos              0.05785
# kevin             0.05762
# know              0.05747
# admin             0.05586
# tak               0.05422
# Name: 11, dtype: float64
#
# Component number: 12
# quest                0.43742
# yo                   0.37430
# wil                  0.22630
# al                   0.14290
# country              0.11265
# ye                   0.11208
# mark                 0.10265
# start                0.10014
# 99                   0.09476
# the_united_states    0.09307
# good                 0.06976
# afternoon            0.06434
# world                0.06433
# press                0.06190
# rel                  0.05996
# Name: 12, dtype: float64
#
# Component number: 13
# michel            0.96368
# quest             0.12478
# wil               0.11684
# yo                0.06945
# ther              0.03272
# ye                0.03171
# democr            0.02732
# intellig          0.02112
# ar                0.01915
# republ            0.01913
# happy             0.01855
# the_white_hous    0.01774
# josh              0.01754
# som               0.01624
# commun            0.01566
# Name: 13, dtype: float64
#
# Component number: 14
# wil          0.50644
# think        0.31014
# wel          0.18983
# intellig     0.15354
# going        0.13062
# democr       0.12812
# mor          0.12812
# commun       0.12196
# look         0.11861
# tomorrow     0.11755
# republ       0.11267
# mak          0.10330
# okay         0.09986
# everybody    0.09024
# elect        0.08621
# Name: 14, dtype: float64
#
# Component number: 15
# thi         0.31133
# quest       0.27231
# ar          0.24475
# admin       0.15673
# wel         0.11821
# okay        0.11590
# think       0.10719
# intellig    0.09838
# report      0.09200
# commun      0.09013
# serv        0.08716
# thes        0.08688
# il          0.07776
# incom       0.07237
# yo          0.07196
# Name: 15, dtype: float64
#
# Component number: 16
# laught               0.51522
# al                   0.17465
# im                   0.15435
# going                0.14797
# michel               0.12081
# know                 0.11596
# mak                  0.09132
# thos                 0.08251
# wil                  0.08030
# dont                 0.07940
# commun               0.07784
# wel                  0.06916
# intellig             0.06381
# the_united_states    0.06166
# right                0.05890
# Name: 16, dtype: float64
#
# Component number: 17
# ther        0.37373
# think       0.28106
# 99          0.19569
# wel         0.17268
# wer         0.14648
# dont        0.12877
# know        0.12195
# mor         0.10369
# al          0.10329
# right       0.09767
# okay        0.08717
# talk        0.08493
# tim         0.08040
# tomorrow    0.07065
# som         0.06614
# Name: 17, dtype: float64
#
# Component number: 18
# 99            0.39272
# thi           0.35033
# intellig      0.16460
# report        0.15239
# commun        0.15008
# mor           0.12002
# ther          0.11821
# laught        0.11383
# tim           0.10453
# job           0.10112
# brief         0.09993
# 99_percent    0.08181
# new           0.08059
# good          0.07777
# grow          0.07239
# Name: 18, dtype: float64
#
# Component number: 19
# dont       0.32751
# think      0.30951
# wil        0.16870
# know       0.14345
# al         0.12137
# russ       0.11229
# right      0.10376
# ye         0.10292
# doe        0.10164
# josh       0.08944
# want       0.08676
# okay       0.07685
# country    0.07388
# thi        0.06238
# meet       0.06087
# Name: 19, dtype: float64

# %% [markdown]
# **kmeans**

# %%
cluster_num = 40
km = KMeans(n_clusters = cluster_num, random_state = 42)
km.fit(lsa_vecs)

# predict one cluster per document
predicted_cluster = km.predict(lsa_vecs)

# %%
df = pd.DataFrame(lsa_vecs[:,0:2], columns = ['first_feat', 'second_feat'])
df['cluster_c'] = predicted_cluster

sns.lmplot(x = 'first_feat', y='second_feat', hue = 'cluster_c', data = df, fit_reg = False, size = 7)

# %%
#lsa.explained_variance_ratio_

# %%
# km.cluster_centers_.shape

# %%
# original_space_centroids.shape

# %%
# order_centroids

# %%
original_space_centroids = lsa.inverse_transform(km.cluster_centers_)
order_centroids = original_space_centroids.argsort()[:, ::-1]

# %%
for i in range(cluster_num):
    print("Cluster %d:" % i, end='')
    print(" ")
    for ind in order_centroids[i, :20]:
        print(' %s' % terms[ind], end='')  # print words in clusters
        print("")
    print(" ")
    print(" ")
print()
# Out:
# Cluster 0:
#  new
#  thi
#  hav
#  report
#  conf
#  ar
#  org
#  presid
#  mr
#  admin
#  ther
#  annount
#  dont
#  wer
#  today
#  som
#  com
#  earnest
#  anyth
#  seen
#
#
# Cluster 1:
#  intellig
#  commun
#  inform
#  assess
#  presid
#  report
#  hav
#  thi
#  ther
#  stat
#  elect
#  think
#  mr
#  direct
#  publ
#  confid
#  earnest
#  bef
#  russ
#  som
#
#
# Cluster 2:
#  respons
#  thi
#  ther
#  presid
#  proport
#  hav
#  publ
#  ar
#  som
#  congress
#  point
#  govern
#  discuss
#  think
#  sery
#  mr
#  wil
#  earnest
#  wel
#  im
#
#
# Cluster 3:
#  ar
#  ther
#  peopl
#  thi
#  thos
#  hav
#  som
#  wer
#  thing
#  presid
#  mor
#  know
#  oth
#  think
#  mak
#  wher
#  al
#  just
#  stil
#  certain
#
#
# Cluster 4:
#  thank
#  josh
#  everybody
#  mr
#  tomorrow
#  earnest
#  wel
#  al
#  apprecy
#  presid
#  yo
#  thi
#  right
#  admin
#  guy
#  hav
#  er
#  sur
#  want
#  press
#
#
# Cluster 5:
#  mr
#  earnest
#  wel
#  im
#  schultz
#  sur
#  yeah
#  ther
#  right
#  thi
#  wil
#  dont
#  hav
#  point
#  aw
#  rul
#  tim
#  know
#  post
#  numb
#
#
# Cluster 6:
#  99
#  99_percent
#  rat
#  job
#  grow
#  sint
#  presid
#  wag
#  unemploy
#  econom
#  hav
#  thi
#  ar
#  record
#  wer
#  ov
#  wev
#  just
#  think
#  cre
#
#
# Cluster 7:
#  hav
#  dont
#  mr
#  earnest
#  thi
#  know
#  som
#  com
#  presid
#  wel
#  want
#  report
#  convers
#  ther
#  tim
#  process
#  the_white_hous
#  thos
#  decid
#  talk
#
#
# Cluster 8:
#  republ
#  congress
#  hav
#  democr
#  ar
#  thi
#  presid
#  sen
#  nomin
#  support
#  wel
#  forward
#  ther
#  polit
#  country
#  consid
#  think
#  act
#  idea
#  som
#
#
# Cluster 9:
#  yo
#  quest
#  say
#  al
#  thi
#  talk
#  hav
#  lik
#  just
#  going
#  want
#  ar
#  ther
#  look
#  mr
#  way
#  said
#  start
#  presid
#  think
#
#
# Cluster 10:
#  heal
#  mark
#  the_affordable_care_act
#  ins
#  car
#  rep
#  hav
#  peopl
#  republ
#  protect
#  99_million
#  becaus
#  ar
#  access
#  company
#  going
#  law
#  cost
#  thos
#  preex
#
#
# Cluster 11:
#  ye
#  earnest
#  mr
#  sir
#  schultz
#  anticip
#  wil
#  il
#  theyr
#  exact
#  laught
#  work
#  lot
#  confid
#  quick
#  disput
#  presid
#  ar
#  okay
#  aft
#
#
# Cluster 12:
#  kevin
#  thank
#  start
#  stephany
#  opportun
#  earnest
#  apprecy
#  mr
#  want
#  polit
#  republ
#  com
#  im
#  going
#  wel
#  predict
#  washington
#  told
#  behavy
#  expery
#
#
# Cluster 13:
#  ir
#  sanct
#  nuclear
#  intern
#  weapon
#  north_korea
#  deal
#  agr
#  program
#  obtain
#  prev
#  thi
#  hav
#  ar
#  impos
#  concern
#  act
#  becaus
#  the_united_states
#  auth
#
#
# Cluster 14:
#  okay
#  earnest
#  mr
#  laught
#  wel
#  good
#  cr
#  gre
#  mor
#  yo
#  barney
#  thank
#  mcgurk
#  presid
#  mayb
#  welcom
#  schultz
#  tomorrow
#  bef
#  look
#
#
# Cluster 15:
#  thes
#  ar
#  hav
#  kind
#  thi
#  presid
#  som
#  wer
#  think
#  act
#  work
#  wil
#  country
#  ther
#  the_united_states
#  issu
#  continu
#  peopl
#  earnest
#  mr
#
#
# Cluster 16:
#  solv
#  diplom
#  syr
#  resolv
#  viol
#  milit
#  israel
#  try
#  the_united_states
#  act
#  thi
#  hav
#  continu
#  situ
#  intern
#  settl
#  ther
#  aleppo
#  wev
#  russ
#
#
# Cluster 17:
#  michel
#  follow
#  littl
#  aft
#  want
#  said
#  tim
#  nat
#  ear
#  presid
#  blood
#  fresh
#  exchang
#  eight_years
#  stag
#  bit
#  unacceiv
#  sec
#  bound
#  ourselv
#
#
# Cluster 18:
#  russ
#  thi
#  elect
#  act
#  wer
#  diplom
#  ar
#  stat
#  hav
#  say
#  govern
#  rel
#  som
#  effort
#  presid
#  ther
#  respons
#  admin
#  intellig
#  said
#
#
# Cluster 19:
#  cub
#  policy
#  migr
#  thi
#  country
#  ar
#  rel
#  peopl
#  wil
#  chang
#  govern
#  travel
#  rep
#  hum
#  hav
#  ther
#  the_cuban_adjustment_act
#  the_united_states
#  law
#  thos
#
#
# Cluster 20:
#  democr
#  presid
#  country
#  ther
#  thi
#  ar
#  hav
#  sen
#  peopl
#  wil
#  republ
#  think
#  al
#  mor
#  work
#  way
#  thos
#  fight
#  som
#  lead
#
#
# Cluster 21:
#  end
#  ir
#  mayb
#  9999
#  chang
#  nat
#  huh
#  wel
#  earnest
#  bring
#  uran
#  jcpoa
#  mr
#  near
#  viol
#  sec
#  foot
#  nuclear
#  another_99_years
#  the_cabinet_ambassadors
#
#
# Cluster 22:
#  wil
#  presid
#  the_white_hous
#  meet
#  thi
#  look
#  ther
#  mr
#  attend
#  hav
#  earnest
#  wel
#  som
#  tel
#  thos
#  tak
#  ev
#  staff
#  the_united_states
#  hop
#
#
# Cluster 23:
#  econom
#  admin
#  incom
#  hav
#  presid
#  policy
#  thi
#  strategy
#  obam
#  work
#  wel
#  wil
#  pursu
#  diff
#  job
#  way
#  good
#  country
#  approach
#  ar
#
#
# Cluster 24:
#  let
#  il
#  mr
#  earnest
#  wel
#  thi
#  know
#  hav
#  quest
#  som
#  speak
#  look
#  just
#  tim
#  investig
#  com
#  earnest_ill
#  tak
#  sen
#  im
#
#
# Cluster 25:
#  act
#  cyb
#  malicy
#  russ
#  elect
#  intellig
#  thi
#  commun
#  mr
#  just
#  eng
#  count
#  wer
#  hav
#  ar
#  ther
#  russia
#  the_united_states
#  govern
#  interf
#
#
# Cluster 26:
#  laught
#  earnest
#  mr
#  im
#  thank
#  say
#  yeah
#  mayb
#  hav
#  going
#  yo
#  wel
#  presid
#  said
#  good
#  ev
#  cov
#  just
#  did
#  anyth
#
#
# Cluster 27:
#  john
#  il
#  giv
#  yo
#  coupl
#  earnest
#  ahead
#  mr
#  wel
#  lay
#  let
#  welcom
#  week
#  mor
#  iv
#  opportun
#  enjoy
#  work
#  ext
#  nam
#
#
# Cluster 28:
#  isil
#  fight
#  syr
#  coalit
#  op
#  iraq
#  thi
#  ar
#  hav
#  forc
#  turkey
#  ter
#  wer
#  ground
#  raqq
#  attack
#  al
#  tak
#  campaign
#  glob
#
#
# Cluster 29:
#  bil
#  pass
#  sign
#  republ
#  presid
#  congress
#  sen
#  legisl
#  support
#  thi
#  fund
#  cr
#  hav
#  veto
#  admin
#  someth
#  ar
#  problem
#  wel
#  provid
#
#
# Cluster 30:
#  cal
#  phon
#  presidentelect
#  presid
#  hav
#  thi
#  mr
#  thank
#  ask
#  want
#  earnest
#  convers
#  the_white_hous
#  tim
#  telephon
#  today
#  conclud
#  ment
#  quest
#  ar
#
#
# Cluster 31:
#  thi
#  giv
#  ahead
#  mor
#  ayesh
#  want
#  right
#  il
#  justin
#  say
#  im
#  just
#  did
#  jord
#  tolus
#  inaud
#  al
#  nic
#  margaret
#  lik
#
#
# Cluster 32:
#  transit
#  smoo
#  team
#  effect
#  presid
#  admin
#  ens
#  hav
#  trump
#  presidentelect
#  commit
#  incom
#  thi
#  ther
#  wer
#  mr
#  diff
#  obam
#  ar
#  elect
#
#
# Cluster 33:
#  ron
#  dac
#  frust
#  debt
#  presidentelect_donald_trump
#  tweet
#  pot
#  margin
#  fut
#  underestim
#  took
#  begun
#  scen
#  beneficy
#  shouldnt
#  earlier_in
#  dysfunct
#  ess
#  99th
#  sabot
#
#
# Cluster 34:
#  serv
#  sec
#  country
#  presid
#  nat
#  the_united_states
#  thos
#  thi
#  work
#  hav
#  wom
#  men
#  al
#  obam
#  peopl
#  ar
#  clos
#  protect
#  wel
#  believ
#
#
# Cluster 35:
#  going
#  thi
#  ar
#  im
#  wer
#  ther
#  presid
#  hav
#  process
#  admin
#  mor
#  think
#  mr
#  said
#  theyr
#  wil
#  hes
#  way
#  say
#  mean
#
#
# Cluster 36:
#  quest
#  ask
#  thi
#  tak
#  answ
#  hav
#  im
#  think
#  want
#  happy
#  mr
#  presid
#  rais
#  ther
#  som
#  wil
#  look
#  wel
#  presidentelect
#  follow
#
#
# Cluster 37:
#  think
#  thi
#  mr
#  presid
#  earnest
#  dont
#  wel
#  ther
#  hav
#  mak
#  som
#  thing
#  just
#  ar
#  peopl
#  elect
#  im
#  way
#  talk
#  wer
#
#
# Cluster 38:
#  hack
#  russ
#  thi
#  elect
#  dnc
#  intellig
#  email
#  leak
#  say
#  ther
#  the_white_hous
#  wer
#  act
#  donald_trump
#  fact
#  int
#  just
#  inform
#  said
#  hav
#
#
# Cluster 39:
#  presid
#  obam
#  thi
#  hav
#  mr
#  ther
#  tim
#  al
#  hes
#  the_united_states
#  earnest
#  said
#  wel
#  im
#  som
#  doe
#  just
#  opportun
#  giv
#  presidentelect

# %% [markdown]
# **dbscan**

# %%
db = DBSCAN(eps = 0.5)
predicted_cluster = db.fit_predict(lsa_vecs)

# %%
df = pd.DataFrame(lsa_vecs[:,0:2], columns = ['first_feat', 'second_feat'])
df['cluster_c'] = predicted_cluster

# noisy samples are given the label -1 so not plotting
sns.lmplot(x = 'first_feat', y='second_feat', hue = 'cluster_c', data = df[df.cluster_c != -1], fit_reg = False)

# %%
# get cluster centers
n_clusters = 32
clusters = [lsa_vecs[db.labels_ == i] for i in range(n_clusters)]

master = []
for i in range(n_clusters):
    cent = list(np.mean(clusters[i], axis = 0))
    master.append(cent)
cluster_centers = np.reshape(master, (32, 300))

# %%
original_space_centroids = lsa.inverse_transform(cluster_centers)
order_centroids = original_space_centroids.argsort()[:, ::-1]

# %%
for i in range(31):
    print("Cluster %d:" % i, end='')
    print(" ")
    for ind in order_centroids[i, :20]:
        print(' %s' % terms[ind], end='')  # print words in clusters
        print("")
    print(" ")
    print(" ")
print()
# Out:
# Cluster 0:
#  thank
#  earnest
#  mr
#  bret
#  er
#  stop
#  apprecy
#  sir
#  richard
#  everybody
#  mcgurk
#  goy
#  jen
#  circ
#  guy
#  behalf
#  hi
#  yem
#  stephany
#  schultz_good
#
#
# Cluster 1:
#  okay
#  earnest
#  mr
#  barney
#  presid
#  cr
#  mcgurk
#  twic
#  inquiry
#  comfort
#  half_an_hour
#  late_night
#  oh
#  holiday
#  scheduled
#  friday_night
#  yesterday
#  thought
#  regul
#  short
#
#
# Cluster 2:
#  olivy
#  hadnt
#  hel
#  outcom
#  nev
#  detect
#  dumber
#  dumb
#  twoandahalfyear
#  movy
#  chant
#  tamp
#  let
#  quot
#  regret
#  fun
#  dec
#  january_99th
#  determin
#  spent
#
#
# Cluster 3:
#  michel
#  blood
#  unacceiv
#  fresh
#  exchang
#  bound
#  stag
#  ourselv
#  eight_years
#  fre
#  outsid
#  depend
#  tri
#  goe
#  cont
#  funct
#  repres
#  handl
#  discount
#  washington
#
#
# Cluster 4:
#  justin
#  earnest
#  mr
#  mou
#  flint
#  piec
#  money
#  pow
#  evid
#  problem
#  best
#  pay
#  complet
#  rhet
#  nat
#  underpin
#  fault
#  ourselv
#  root
#  famili
#
#
# Cluster 5:
#  mor
#  il
#  wer
#  going
#  im
#  presidentelect
#  kevin
#  concern
#  wel
#  convers
#  jord
#  hav
#  gre
#  shar
#  ar
#  olivy
#  process
#  mark
#  ther
#  admin
#
#
# Cluster 6:
#  april
#  cov
#  wasnt
#  the_first_days
#  debilit
#  esp
#  delay
#  october_99th
#  mistak
#  prop
#  wor
#  caus
#  month
#  tie
#  knew
#  attribut
#  dnc
#  form
#  foreign
#  leak
#
#
# Cluster 7:
#  thi
#  commun
#  think
#  tomorrow
#  thank
#  fact
#  cas
#  benefit
#  dav
#  meet
#  want
#  everybody
#  let
#  mat
#  understand
#  intellig
#  99
#  end
#  giv
#  view
#
#
# Cluster 8:
#  margaret
#  earnest
#  mr
#  nic
#  uneas
#  level
#  overthetop
#  rhodes_sure
#  singl
#  sound
#  flaw
#  pretty
#  samanth
#  oft
#  frequ
#  abstain
#  the_united_nations
#  venu
#  prob
#  curv
#
#
# Cluster 9:
#  mr
#  earnest
#  schultz
#  trump
#  saw
#  absolv
#  check
#  ref
#  watch
#  long
#  earnest_ill
#  confirm
#  high
#  isnt
#  earnest_john
#  donald_trump
#  il
#  earnest_happy_new_year
#  earnest_ron
#  bret
#
#
# Cluster 10:
#  jord
#  choos
#  subst
#  declass
#  man
#  retain
#  vary
#  rememb
#  dib
#  regim
#  sum
#  port
#  occas
#  impos
#  edward_snowden
#  snowd
#  fair
#  weigh
#  requir
#  pardon
#
#
# Cluster 11:
#  apprecy
#  stil
#  gardin
#  sam
#  sorry
#  sint
#  somebody
#  jean
#  polit
#  second
#  releas
#  way
#  margaret
#  nic
#  set
#  sen
#  tru
#  mat
#  syr
#  cas
#
#
# Cluster 12:
#  ye
#  sir
#  anticip
#  disput
#  maam
#  clar
#  hand
#  quick
#  late_night
#  friday_night
#  particip
#  sint
#  ahead
#  receiv
#  exerc
#  incumb
#  outoftown
#  liv
#  short
#  und
#
#
# Cluster 13:
#  kevin
#  stephany
#  predict
#  expery
#  washington
#  told
#  behavy
#  wont
#  leg
#  israel
#  opportun
#  manufact
#  socy
#  root
#  nato
#  ent
#  situ
#  pray
#  _eastern
#  grand
#
#
# Cluster 14:
#  ron
#  dac
#  frust
#  debt
#  presidentelect_donald_trump
#  tweet
#  pot
#  margin
#  fut
#  underestim
#  took
#  begun
#  scen
#  beneficy
#  shouldnt
#  earlier_in
#  dysfunct
#  ess
#  99th
#  sabot
#
#
# Cluster 15:
#  mark
#  asterisk
#  mr
#  earnest
#  trust
#  schultz_we
#  indulg
#  mem
#  goy
#  weekend
#  overshoot
#  vict
#  wont
#  pleas
#  annivers
#  iow
#  the_first_days
#  that_day
#  improv
#  thought
#
#
# Cluster 16:
#  yeah
#  earnest
#  mr
#  lit
#  weekahead
#  ar
#  wil
#  friend
#  earnest_falsely
#  wrong
#  oh
#  rememb
#  the_department_of_justic
#  readout
#  kid
#  post
#  tag
#  stretched
#  wont
#  seat
#
#
# Cluster 17:
#  ahead
#  week
#  jc
#  juliann
#  ben
#  goy
#  schultz_good
#  sir
#  _ill
#  the_week
#  darl
#  footbal
#  gam
#  view
#  lie
#  stay
#  run
#  requir
#  quick
#  company
#
#
# Cluster 18:
#  sur
#  earnest
#  mr
#  quit
#  mak
#  oh
#  im
#  reason
#  applaus
#  learn
#  cur
#  whol
#  necess
#  the_six_nations
#  transit
#  aleppo
#  pleas
#  schultz_hans
#  cle
#  yesterday
#
#
# Cluster 19:
#  ye
#  earnest
#  mr
#  sir
#  ar
#  anticip
#  disput
#  maam
#  clar
#  particip
#  late_night
#  friday_night
#  exerc
#  outoftown
#  quick
#  liv
#  short
#  fair
#  incumb
#  ess
#
#
# Cluster 20:
#  john
#  lay
#  enjoy
#  coupl
#  ext
#  profound
#  garn
#  nam
#  rhet
#  week
#  ukrain
#  the_national_security_council
#  simpl
#  the_department_of_stat
#  cont
#  sufficy
#  il
#  lgbt_americans
#  world_series_championship
#  felt
#
#
# Cluster 21:
#  thank
#  er
#  stop
#  bret
#  guy
#  sir
#  mcgurk
#  hi
#  circ
#  richard
#  everybody
#  jen
#  applaus
#  upd
#  mr
#  goy
#  behalf
#  reason
#  spel
#  stephany
#
#
# Cluster 22:
#  ayesh
#  constrain
#  idea
#  branch
#  liv
#  lov
#  _security_council
#  vessel
#  togeth
#  extraordin
#  mer
#  pretty
#  presidentelect_trump
#  ampl
#  hardnos
#  avail
#  apply
#  describ
#  requir
#  allow
#
#
# Cluster 23:
#  inaud
#  admin
#  wmd
#  joint
#  aid
#  retweet
#  job
#  pak
#  miss
#  invest
#  sixparty
#  thaad
#  weapon
#  troop
#  north_korean
#  north_korea
#  afgh
#  multipl
#  invit
#  stand
#
#
# Cluster 24:
#  meet
#  the_white_hous
#  wil
#  attend
#  presid
#  thursday
#  monday
#  tuesday
#  lady
#  invit
#  particip
#  host
#  wednesday
#  friday
#  mcgurk
#  week
#  wasnt
#  wond
#  address
#  suggest
#
#
# Cluster 25:
#  end
#  9999
#  bring
#  huh
#  uran
#  jcpoa
#  near
#  viol
#  foot
#  ready
#  another_99_years
#  reward
#  the_cabinet_ambassadors
#  prom
#  over_a_year
#  osama_bin_laden
#  north_korea
#  nat
#  depart
#  menac
#
#
# Cluster 26:
#  robert
#  apply
#  congressman_price
#  congressman_prices
#  respect
#  meas
#  impl
#  evalu
#  car
#  heal
#  rais
#  plan
#  fight
#  rep
#  upd
#  argu
#  busy
#  surpr
#  mov
#  fair
#
#
# Cluster 27:
#  tolus
#  resist
#  coalit
#  past
#  yem
#  undermin
#  saudil
#  strikes
#  casual
#  grav
#  simil
#  ongo
#  the_paris_climate_agreement
#  civil
#  unclear
#  assist
#  heard
#  tillerson
#  transpac
#  illust
#
#
# Cluster 28:
#  andrew
#  bret
#  maritim
#  sea
#  allud
#  depl
#  en
#  persist
#  loss
#  remain
#  hand
#  lif
#  reliev
#  flow
#  troubl
#  list
#  facilit
#  year
#  innoc
#  deeply
#
#
# Cluster 29:
#  laught
#  thi
#  presid
#  noth
#  cov
#  hanky
#  funny
#  hand
#  jeopardy
#  more_than_fiv
#  er
#  absolv
#  oh
#  reward
#  away
#  bring
#  necess
#  hear
#  goe
#  spel
#
#
# Cluster 30:
#  say
#  going
#  act
#  mark
#  cal
#  hack
#  continu
#  lik
#  policy
#  sur
#  coupl
#  diff
#  syr
#  michel
#  talk
#  hes
#  ir
#  agr
#  anyth
#  way

# %%
# not doing well...these things shouldn't be clustered

#  the_department_of_stat
#  the_national_security_council
#  lgbt_americans
#  world_series_championship

# %% [markdown]
# ** hierarchical agglomerative clustering**

# %%
cluster_num = 40
hac = AgglomerativeClustering(n_clusters = cluster_num)
# ward is default but worth trying linkage = 'average'
predicted_cluster = hac.fit_predict(lsa_vecs)

# %%
df = pd.DataFrame(lsa_vecs[:,0:2], columns = ['first_feat', 'second_feat'])
df['cluster_c'] = predicted_cluster

sns.lmplot(x = 'first_feat', y='second_feat', hue = 'cluster_c', data = df, fit_reg = False, size = 7)

# %%
# get cluster centers
clusters = [lsa_vecs[hac.labels_ == i] for i in range(cluster_num)]

master = []
for i in range(cluster_num):
    cent = list(np.mean(clusters[i], axis = 0))
    master.append(cent)
cluster_centers = np.reshape(master, (cluster_num, 300))

# %%
original_space_centroids = lsa.inverse_transform(cluster_centers)
order_centroids = original_space_centroids.argsort()[:, ::-1]

for i in range(cluster_num):
    print("Cluster %d:" % i, end='')
    print(" ")
    for ind in order_centroids[i, :20]:
        print(' %s' % terms[ind], end='')  # print words in clusters
        print("")
    print(" ")
    print(" ")
print()
# Out:
# Cluster 0:
#  congress
#  sen
#  republ
#  bil
#  nomin
#  pass
#  presid
#  hav
#  thi
#  memb
#  ther
#  ar
#  wel
#  just
#  think
#  som
#  legisl
#  tak
#  democr
#  wil
#
#
# Cluster 1:
#  russ
#  elect
#  act
#  hack
#  thi
#  intellig
#  cyb
#  malicy
#  wer
#  think
#  hav
#  vot
#  ther
#  polit
#  som
#  ar
#  sery
#  presid
#  say
#  respons
#
#
# Cluster 2:
#  welcom
#  nic
#  sorry
#  margaret
#  jord
#  tolus
#  olivy
#  chris
#  andrew
#  jeff
#  correct
#  robert
#  dav
#  earnest
#  april
#  mr
#  pleas
#  im
#  new
#  yo
#
#
# Cluster 3:
#  mr
#  earnest
#  wel
#  im
#  dont
#  right
#  hav
#  know
#  thi
#  think
#  sur
#  presid
#  schultz
#  point
#  ther
#  aw
#  ar
#  mayb
#  plan
#  annount
#
#
# Cluster 4:
#  syr
#  solv
#  russ
#  milit
#  act
#  ar
#  israel
#  viol
#  try
#  the_united_states
#  hav
#  aleppo
#  thi
#  isil
#  ther
#  world
#  diplom
#  wev
#  resolv
#  tak
#
#
# Cluster 5:
#  quest
#  start
#  good
#  everybody
#  mr
#  earnest
#  afternoon
#  happy
#  yo
#  hav
#  want
#  second
#  josh
#  straight
#  nic
#  com
#  thi
#  mov
#  im
#  wel
#
#
# Cluster 6:
#  report
#  presidentelect
#  hav
#  convers
#  cal
#  mr
#  thi
#  brief
#  presid
#  earnest
#  releas
#  read
#  diff
#  ther
#  wil
#  wel
#  intellig
#  speak
#  ar
#  ref
#
#
# Cluster 7:
#  ayesh
#  thi
#  commun
#  think
#  tomorrow
#  thank
#  fact
#  cas
#  benefit
#  dav
#  meet
#  want
#  everybody
#  let
#  mat
#  understand
#  intellig
#  99
#  end
#  giv
#
#
# Cluster 8:
#  admin
#  policy
#  rel
#  thi
#  presid
#  chin
#  incom
#  hav
#  regard
#  wil
#  the_united_states
#  obam
#  chines
#  agr
#  wel
#  ar
#  think
#  ther
#  ind
#  mr
#
#
# Cluster 9:
#  thi
#  presid
#  hav
#  ar
#  ther
#  think
#  wer
#  som
#  peopl
#  al
#  thos
#  country
#  mr
#  thes
#  mor
#  wil
#  mak
#  going
#  earnest
#  way
#
#
# Cluster 10:
#  presid
#  thi
#  hav
#  wil
#  mr
#  ther
#  think
#  earnest
#  going
#  ar
#  just
#  doe
#  the_white_hous
#  lik
#  som
#  said
#  look
#  tim
#  did
#  quest
#
#
# Cluster 11:
#  cub
#  policy
#  migr
#  wil
#  thi
#  country
#  govern
#  ar
#  peopl
#  travel
#  rep
#  chang
#  oth
#  hum
#  the_cuban_adjustment_act
#  plac
#  rel
#  law
#  think
#  norm
#
#
# Cluster 12:
#  intellig
#  commun
#  inform
#  assess
#  confid
#  russ
#  ther
#  elect
#  presid
#  hav
#  stat
#  think
#  conclud
#  mr
#  publ
#  thi
#  earnest
#  wel
#  mak
#  shar
#
#
# Cluster 13:
#  99
#  rat
#  99_percent
#  grow
#  wag
#  unemploy
#  sint
#  record
#  job
#  econom
#  ov
#  thi
#  incom
#  wev
#  wer
#  reduc
#  hav
#  ar
#  poverty
#  presid
#
#
# Cluster 14:
#  thank
#  everybody
#  tomorrow
#  mr
#  earnest
#  wel
#  okay
#  right
#  weekend
#  er
#  afternoon
#  cal
#  plan
#  al
#  rhodes_great
#  bret
#  mele_kalikimaka
#  happy
#  rest
#  lat
#
#
# Cluster 15:
#  ye
#  earnest
#  mr
#  sir
#  exact
#  anticip
#  okay
#  certain
#  disput
#  thing
#  just
#  quick
#  clar
#  ar
#  maam
#  late_night
#  exerc
#  outoftown
#  particip
#  friday_night
#
#
# Cluster 16:
#  josh
#  thank
#  apprecy
#  yo
#  al
#  earnest
#  mr
#  hav
#  work
#  sur
#  happy_new_year
#  react
#  bret
#  brief
#  indulg
#  long
#  hard
#  press
#  deeply
#  the_white_hous
#
#
# Cluster 17:
#  serv
#  wom
#  men
#  ar
#  presid
#  country
#  adv
#  commun
#  hav
#  intellig
#  the_united_states
#  saf
#  thi
#  thes
#  obam
#  milit
#  expert
#  peopl
#  publ
#  work
#
#
# Cluster 18:
#  inaud
#  sanct
#  north_korea
#  the_united_states
#  protect
#  north_korean
#  ar
#  nuclear
#  south_korea
#  threat
#  missil
#  intern
#  clos
#  cap
#  milit
#  program
#  presid
#  addit
#  deploy
#  regim
#
#
# Cluster 19:
#  yo
#  say
#  press
#  talk
#  mak
#  thi
#  ar
#  argu
#  conf
#  hav
#  presid
#  going
#  just
#  ther
#  job
#  want
#  admin
#  brief
#  mean
#  way
#
#
# Cluster 20:
#  ron
#  dac
#  frust
#  debt
#  presidentelect_donald_trump
#  tweet
#  pot
#  margin
#  fut
#  underestim
#  took
#  begun
#  scen
#  beneficy
#  shouldnt
#  earlier_in
#  dysfunct
#  ess
#  99th
#  sabot
#
#
# Cluster 21:
#  transit
#  smoo
#  effect
#  team
#  presid
#  admin
#  ens
#  presidentelect
#  commit
#  incom
#  wer
#  elect
#  obam
#  thi
#  trump
#  hav
#  respons
#  al
#  diff
#  effort
#
#
# Cluster 22:
#  republ
#  heal
#  the_affordable_care_act
#  democr
#  car
#  ins
#  hav
#  rep
#  presid
#  ar
#  thi
#  peopl
#  forward
#  law
#  ther
#  work
#  idea
#  protect
#  just
#  think
#
#
# Cluster 23:
#  kevin
#  thank
#  stephany
#  opportun
#  predict
#  expery
#  washington
#  told
#  behavy
#  wont
#  israel
#  socy
#  manufact
#  ent
#  root
#  nato
#  leg
#  start
#  er
#  pray
#
#
# Cluster 24:
#  ahead
#  week
#  jc
#  giv
#  juliann
#  il
#  goy
#  sir
#  schultz_good
#  ben
#  let
#  wel
#  hand
#  _ill
#  the_week
#  darl
#  gam
#  footbal
#  quick
#  thank
#
#
# Cluster 25:
#  yeah
#  mr
#  earnest
#  laught
#  post
#  wil
#  schultz
#  weekahead
#  lit
#  il
#  oh
#  earnest_falsely
#  wrong
#  friend
#  right
#  ar
#  sur
#  rememb
#  opportun
#  im
#
#
# Cluster 26:
#  laught
#  earnest
#  mr
#  im
#  going
#  thank
#  say
#  yo
#  ev
#  anyth
#  said
#  just
#  ther
#  hav
#  got
#  presid
#  quest
#  cov
#  try
#  ar
#
#
# Cluster 27:
#  mr
#  earnest
#  schultz
#  wil
#  ther
#  ar
#  someth
#  trump
#  saw
#  agr
#  stat
#  absolv
#  class
#  presid
#  confid
#  check
#  look
#  high
#  sery
#  lik
#
#
# Cluster 28:
#  isil
#  fight
#  op
#  iraq
#  coalit
#  forc
#  syr
#  ar
#  hav
#  turkey
#  ter
#  raqq
#  ground
#  campaign
#  thi
#  attack
#  glob
#  lead
#  partn
#  wev
#
#
# Cluster 29:
#  justin
#  earnest
#  mr
#  mou
#  flint
#  piec
#  money
#  pow
#  evid
#  problem
#  best
#  pay
#  complet
#  rhet
#  nat
#  underpin
#  fault
#  ourselv
#  root
#  famili
#
#
# Cluster 30:
#  mark
#  laught
#  yo
#  mr
#  start
#  earnest
#  want
#  coupl
#  asterisk
#  numb
#  today
#  plan
#  bef
#  discuss
#  trust
#  act
#  hop
#  al
#  thought
#  thank
#
#
# Cluster 31:
#  michel
#  blood
#  unacceiv
#  fresh
#  exchang
#  bound
#  stag
#  ourselv
#  eight_years
#  fre
#  outsid
#  depend
#  tri
#  goe
#  cont
#  funct
#  repres
#  handl
#  discount
#  washington
#
#
# Cluster 32:
#  say
#  going
#  act
#  mark
#  cal
#  hack
#  continu
#  lik
#  policy
#  sur
#  coupl
#  diff
#  syr
#  michel
#  talk
#  hes
#  ir
#  agr
#  anyth
#  way
#
#
# Cluster 33:
#  john
#  yo
#  il
#  earnest
#  coupl
#  mr
#  giv
#  lay
#  welcom
#  let
#  mor
#  iv
#  opportun
#  enjoy
#  work
#  wel
#  week
#  ext
#  nam
#  profound
#
#
# Cluster 34:
#  ir
#  nuclear
#  weapon
#  deal
#  intern
#  obtain
#  prev
#  agr
#  sanct
#  legisl
#  concern
#  auth
#  program
#  hav
#  world
#  al
#  becaus
#  thi
#  impos
#  nat
#
#
# Cluster 35:
#  end
#  9999
#  bring
#  huh
#  uran
#  jcpoa
#  near
#  viol
#  foot
#  ready
#  another_99_years
#  reward
#  the_cabinet_ambassadors
#  prom
#  over_a_year
#  osama_bin_laden
#  north_korea
#  nat
#  depart
#  menac
#
#
# Cluster 36:
#  meet
#  the_white_hous
#  attend
#  presid
#  wil
#  thursday
#  monday
#  thos
#  particip
#  russ
#  wasnt
#  mcgurk
#  tuesday
#  going
#  way
#  mess
#  ar
#  ongo
#  g99
#  wer
#
#
# Cluster 37:
#  il
#  let
#  giv
#  jar
#  mr
#  earnest
#  wel
#  quest
#  kind
#  yo
#  sen
#  know
#  som
#  hav
#  francesc
#  want
#  thi
#  ther
#  try
#  presid
#
#
# Cluster 38:
#  econom
#  strategy
#  job
#  hav
#  presid
#  pursu
#  good
#  99
#  obam
#  wel
#  work
#  country
#  ar
#  diff
#  mor
#  admin
#  opportun
#  sint
#  wer
#  think
#
#
# Cluster 39:
#  okay
#  earnest
#  mr
#  laught
#  wel
#  good
#  thank
#  cr
#  gre
#  know
#  barney
#  mcgurk
#  schultz
#  mayb
#  bef
#  look
#  answ
#  presid
#  didnt
#  oh

# %%
# often finds clustesr around:
# syria/russia, north korea/nuclear, health, israel, transition, economy, cuba, intelligence/russia/election, isis

# %% [markdown]
# ### code to get clusters into dfs to visualize

# %%
# docs5000 = df2[:5000].reset_index().drop('index', axis = 1)
# merged_df = pd.concat([docs5000, df], axis = 1)
# merged_df.head()
# merged_df['week_start']=merged_df['dt']-pd.DateOffset(weekday=0,weeks=1)
# # only 8 weeks in test data
# merged_df.week_start.value_counts()

# cluster_df_long = merged_df.groupby(['week_start', 'cluster_c'])['paragraph'].count().reset_index()
# cluster_df_long.head()
# cluster_df = cluster_df_long.pivot(index='week_start', columns='cluster_c', values='paragraph').reset_index()
# cluster_df.fillna(0, inplace = True)
# cluster_df.head()

# cluster_words = []
# for i in range(cluster_num):
#     words = []
#     for ind in order_centroids[i, :15]:
#         words.append(terms[ind])
#     cluster_words.append(words)
    
# cluster_words = (np.reshape(cluster_words, (cluster_num, 15)))

# word_list = cluster_words.tolist()
# words_df = pd.DataFrame(list(range(40)), columns = ['cluster'])
# words_df['words'] = pd.Series(word_list)
# words_df['words'] = words_df.words.map(lambda x: str(x)).str.strip('[]')
# words_df = words_df.transpose().drop('cluster', axis = 0)

# nums = list(range(40))
# new_nums = []
# for i in nums:
#     x = 'c' + str(i)
#     new_nums.append(x)
    
# words_df.columns = [new_nums]
# words_df.head()

# %% [markdown]
# ** spectral clustering**

# %%
# this may not need to be normalized first...
cluster_num = 40
spec = SpectralClustering(n_clusters = cluster_num)
predicted_cluster = spec.fit_predict(lsa_vecs)

# %%
df = pd.DataFrame(lsa_vecs[:,0:2], columns = ['first_feat', 'second_feat'])
df['cluster_c'] = predicted_cluster

sns.lmplot(x = 'first_feat', y='second_feat', hue = 'cluster_c', data = df, fit_reg = False, size = 7)

# %%
# get cluster centers
n_clusters = 40
clusters = [lsa_vecs[spec.labels_ == i] for i in range(n_clusters)]

master = []
for i in range(n_clusters):
    cent = list(np.mean(clusters[i], axis = 0))
    master.append(cent)
cluster_centers = np.reshape(master, (40, 300))

# %%
original_space_centroids = lsa.inverse_transform(cluster_centers)
order_centroids = original_space_centroids.argsort()[:, ::-1]

for i in range(cluster_num):
    print("Cluster %d:" % i, end='')
    print(" ")
    for ind in order_centroids[i, :20]:
        print(' %s' % terms[ind], end='')  # print words in clusters
        print("")
    print(" ")
    print(" ")
print()
# Out:
# Cluster 0:
#  ayesh
#  justin
#  yeah
#  mor
#  thi
#  earnest
#  commun
#  mr
#  cas
#  tomorrow
#  mat
#  want
#  thank
#  fact
#  gardin
#  nic
#  argu
#  meet
#  apprecy
#  dav
#
#
# Cluster 1:
#  think
#  mr
#  earnest
#  thi
#  presid
#  dont
#  wel
#  hav
#  ther
#  ar
#  som
#  ind
#  thing
#  al
#  peopl
#  just
#  say
#  thos
#  way
#  said
#
#
# Cluster 2:
#  wer
#  ther
#  going
#  thi
#  thos
#  som
#  hav
#  mor
#  report
#  tim
#  al
#  mad
#  presid
#  peopl
#  think
#  mr
#  decid
#  concern
#  said
#  tak
#
#
# Cluster 3:
#  kevin
#  thank
#  start
#  stephany
#  opportun
#  want
#  expery
#  predict
#  told
#  washington
#  behavy
#  wont
#  israel
#  socy
#  ent
#  manufact
#  er
#  leg
#  root
#  nato
#
#
# Cluster 4:
#  admin
#  incom
#  thi
#  transit
#  hav
#  presid
#  wel
#  team
#  policy
#  obam
#  wil
#  presidentelect
#  trump
#  think
#  strategy
#  smoo
#  pursu
#  diff
#  econom
#  mr
#
#
# Cluster 5:
#  ron
#  dac
#  frust
#  debt
#  presidentelect_donald_trump
#  tweet
#  pot
#  margin
#  fut
#  underestim
#  took
#  begun
#  scen
#  beneficy
#  shouldnt
#  earlier_in
#  dysfunct
#  ess
#  99th
#  sabot
#
#
# Cluster 6:
#  presid
#  obam
#  hav
#  hes
#  mr
#  tim
#  thi
#  ther
#  earnest
#  think
#  wel
#  doe
#  certain
#  going
#  did
#  som
#  al
#  giv
#  said
#  peopl
#
#
# Cluster 7:
#  laught
#  earnest
#  mr
#  im
#  say
#  thank
#  mayb
#  yeah
#  going
#  wel
#  yo
#  hav
#  said
#  ev
#  real
#  ther
#  did
#  presid
#  good
#  cov
#
#
# Cluster 8:
#  mark
#  start
#  laught
#  numb
#  asterisk
#  want
#  trust
#  mr
#  earnest
#  schultz_we
#  mem
#  indulg
#  goy
#  weekend
#  overshoot
#  pleas
#  vict
#  iow
#  wont
#  annivers
#
#
# Cluster 9:
#  thank
#  mr
#  earnest
#  josh
#  er
#  guy
#  bret
#  work
#  al
#  stop
#  yo
#  hard
#  apprecy
#  sound
#  sort
#  applaus
#  press
#  behalf
#  jen
#  sir
#
#
# Cluster 10:
#  okay
#  earnest
#  mr
#  laught
#  wel
#  cr
#  gre
#  thank
#  good
#  barney
#  bef
#  mcgurk
#  look
#  presid
#  comfort
#  holiday
#  twic
#  inquiry
#  oh
#  half_an_hour
#
#
# Cluster 11:
#  end
#  9999
#  bring
#  huh
#  uran
#  jcpoa
#  near
#  viol
#  foot
#  ready
#  another_99_years
#  reward
#  the_cabinet_ambassadors
#  prom
#  over_a_year
#  osama_bin_laden
#  north_korea
#  nat
#  depart
#  menac
#
#
# Cluster 12:
#  mr
#  earnest
#  wel
#  ther
#  say
#  let
#  did
#  lik
#  presid
#  nic
#  becaus
#  mor
#  just
#  the_white_hous
#  com
#  oth
#  mean
#  jord
#  someth
#  doe
#
#
# Cluster 13:
#  ye
#  earnest
#  mr
#  sir
#  exact
#  anticip
#  schultz
#  okay
#  theyr
#  disput
#  certain
#  thing
#  quick
#  just
#  clar
#  ar
#  maam
#  act
#  exerc
#  particip
#
#
# Cluster 14:
#  republ
#  congress
#  democr
#  sen
#  presid
#  hav
#  bil
#  thi
#  pass
#  ar
#  ther
#  nomin
#  work
#  support
#  sign
#  going
#  vot
#  rep
#  wil
#  just
#
#
# Cluster 15:
#  ar
#  ther
#  thes
#  hav
#  going
#  som
#  thos
#  peopl
#  thing
#  mr
#  presid
#  thi
#  earnest
#  the_united_states
#  think
#  kind
#  wel
#  mor
#  wher
#  respons
#
#
# Cluster 16:
#  country
#  presid
#  work
#  the_united_states
#  peopl
#  mak
#  hav
#  ar
#  thos
#  sec
#  al
#  econom
#  serv
#  thi
#  way
#  world
#  import
#  mor
#  protect
#  obam
#
#
# Cluster 17:
#  heal
#  the_affordable_care_act
#  ins
#  car
#  republ
#  hav
#  rep
#  peopl
#  ar
#  protect
#  99_million
#  becaus
#  access
#  mor
#  cost
#  company
#  grow
#  preex
#  impact
#  condit
#
#
# Cluster 18:
#  josh
#  thank
#  want
#  presid
#  start
#  report
#  today
#  ask
#  quest
#  doe
#  hav
#  brief
#  press
#  yo
#  said
#  ther
#  sur
#  thi
#  the_white_hous
#  react
#
#
# Cluster 19:
#  intellig
#  commun
#  assess
#  inform
#  report
#  presid
#  hav
#  ther
#  thi
#  mr
#  direct
#  confid
#  think
#  earnest
#  stat
#  russ
#  wel
#  som
#  publ
#  brief
#
#
# Cluster 20:
#  im
#  mr
#  earnest
#  sur
#  aw
#  going
#  wel
#  presid
#  just
#  hav
#  respons
#  thi
#  sorry
#  ther
#  ar
#  mak
#  say
#  wond
#  try
#  point
#
#
# Cluster 21:
#  cub
#  policy
#  migr
#  thi
#  country
#  ar
#  govern
#  rel
#  peopl
#  wil
#  chang
#  rep
#  travel
#  hav
#  hum
#  law
#  the_united_states
#  the_cuban_adjustment_act
#  thos
#  ther
#
#
# Cluster 22:
#  john
#  coupl
#  let
#  yo
#  lay
#  mor
#  earnest
#  mr
#  enjoy
#  ext
#  nam
#  profound
#  garn
#  ukrain
#  rhet
#  week
#  simpl
#  the_national_security_council
#  the_department_of_stat
#  sufficy
#
#
# Cluster 23:
#  russ
#  act
#  cyb
#  malicy
#  thi
#  elect
#  wer
#  intellig
#  hack
#  govern
#  say
#  hav
#  ar
#  did
#  stat
#  just
#  som
#  respons
#  oth
#  ther
#
#
# Cluster 24:
#  mr
#  earnest
#  schultz
#  ther
#  doe
#  absolv
#  high
#  saw
#  trump
#  cal
#  ment
#  particul
#  term
#  tak
#  bef
#  cours
#  class
#  bret
#  tru
#  presid
#
#
# Cluster 25:
#  know
#  dont
#  mr
#  hav
#  earnest
#  thi
#  presid
#  wel
#  tim
#  som
#  lik
#  ar
#  want
#  anyth
#  hes
#  ther
#  point
#  going
#  let
#  wil
#
#
# Cluster 26:
#  wil
#  presid
#  the_white_hous
#  earnest
#  mr
#  meet
#  attend
#  ther
#  look
#  thi
#  hav
#  som
#  wel
#  tel
#  thos
#  staff
#  hop
#  anticip
#  trip
#  ev
#
#
# Cluster 27:
#  ir
#  sanct
#  the_united_states
#  intern
#  nuclear
#  diplom
#  solv
#  hav
#  agr
#  weapon
#  syr
#  resolv
#  thi
#  north_korea
#  viol
#  act
#  concern
#  ar
#  russ
#  continu
#
#
# Cluster 28:
#  thi
#  presid
#  point
#  say
#  going
#  mr
#  hav
#  just
#  ther
#  report
#  think
#  ar
#  mor
#  act
#  al
#  someth
#  process
#  tim
#  admin
#  becaus
#
#
# Cluster 29:
#  99
#  99_percent
#  rat
#  job
#  grow
#  sint
#  econom
#  wag
#  unemploy
#  presid
#  record
#  thi
#  hav
#  ar
#  wer
#  wev
#  ov
#  ther
#  cre
#  tim
#
#
# Cluster 30:
#  everybody
#  tomorrow
#  thank
#  good
#  afternoon
#  wel
#  mr
#  earnest
#  nic
#  straight
#  al
#  weekend
#  hav
#  start
#  quest
#  okay
#  annount
#  yo
#  com
#  right
#
#
# Cluster 31:
#  yo
#  say
#  talk
#  quest
#  thi
#  mean
#  just
#  hav
#  al
#  going
#  want
#  ar
#  presid
#  welcom
#  doing
#  way
#  som
#  mr
#  ov
#  ther
#
#
# Cluster 32:
#  il
#  giv
#  ahead
#  week
#  let
#  jc
#  mr
#  goy
#  wel
#  chris
#  hand
#  jar
#  francesc
#  sir
#  hav
#  yo
#  schultz_good
#  _ill
#  juliann
#  turn
#
#
# Cluster 33:
#  michel
#  blood
#  unacceiv
#  fresh
#  exchang
#  bound
#  stag
#  ourselv
#  eight_years
#  fre
#  outsid
#  depend
#  tri
#  goe
#  cont
#  funct
#  repres
#  handl
#  discount
#  washington
#
#
# Cluster 34:
#  isil
#  fight
#  syr
#  iraq
#  coalit
#  op
#  ar
#  thi
#  hav
#  forc
#  ter
#  turkey
#  ground
#  raqq
#  attack
#  tak
#  al
#  wer
#  campaign
#  glob
#
#
# Cluster 35:
#  right
#  al
#  mr
#  earnest
#  hum
#  presid
#  ar
#  just
#  mak
#  decid
#  dont
#  wil
#  didnt
#  nee
#  thi
#  got
#  tel
#  hap
#  pass
#  ther
#
#
# Cluster 36:
#  hav
#  presid
#  som
#  mr
#  ther
#  com
#  earnest
#  thi
#  presidentelect
#  convers
#  dont
#  thos
#  mor
#  cal
#  talk
#  the_white_hous
#  just
#  al
#  wil
#  doe
#
#
# Cluster 37:
#  quest
#  answ
#  ask
#  hav
#  thi
#  yo
#  mr
#  tak
#  im
#  let
#  second
#  som
#  presid
#  think
#  rais
#  earnest
#  wel
#  ther
#  mor
#  wil
#
#
# Cluster 38:
#  say
#  going
#  act
#  mark
#  cal
#  hack
#  continu
#  lik
#  policy
#  sur
#  coupl
#  diff
#  syr
#  michel
#  talk
#  hes
#  ir
#  agr
#  anyth
#  way
#
#
# Cluster 39:
#  elect
#  presid
#  act
#  thi
#  cyb
#  mak
#  hav
#  democr
#  russ
#  malicy
#  interf
#  going
#  review
#  al
#  vot
#  think
#  country
#  result
#  bef
#  admin

# %%
# does okay, buth others do better

# %% [markdown]
# ** Gaussian mixture**

# %%
cluster_num = 40
gm = GaussianMixture(n_components = cluster_num)
gm.fit(lsa_vecs)

# predict one cluster per document
predicted_cluster = gm.predict(lsa_vecs)

# %%
df = pd.DataFrame(lsa_vecs[:,0:2], columns = ['first_feat', 'second_feat'])
df['cluster_c'] = predicted_cluster

sns.lmplot(x = 'first_feat', y='second_feat', hue = 'cluster_c', data = df, fit_reg = False, size = 7)

# %%
# get cluster centers
n_clusters = 40
clusters = [lsa_vecs[predicted_cluster == i] for i in range(n_clusters)]

master = []
for i in range(n_clusters):
    cent = list(np.mean(clusters[i], axis = 0))
    master.append(cent)
cluster_centers = np.reshape(master, (40, 300))

# %%
original_space_centroids = lsa.inverse_transform(cluster_centers)
order_centroids = original_space_centroids.argsort()[:, ::-1]

for i in range(cluster_num):
    print("Cluster %d:" % i, end='')
    print(" ")
    for ind in order_centroids[i, :20]:
        print(' %s' % terms[ind], end='')  # print words in clusters
        print("")
    print(" ")
    print(" ")
print()
# Out:
# Cluster 0:
#  ye
#  mr
#  earnest
#  sir
#  schultz
#  anticip
#  sign
#  theyr
#  wil
#  exact
#  hand
#  confid
#  lot
#  il
#  ar
#  quick
#  okay
#  disput
#  aft
#  the_united_states
#
#
# Cluster 1:
#  thos
#  peopl
#  ar
#  hav
#  thi
#  country
#  mak
#  serv
#  way
#  presid
#  al
#  valu
#  report
#  becaus
#  kind
#  ev
#  wer
#  import
#  ther
#  lot
#
#
# Cluster 2:
#  convers
#  presidentelect
#  hav
#  presid
#  mr
#  cal
#  earnest
#  speak
#  im
#  team
#  thos
#  transit
#  ther
#  going
#  thi
#  som
#  dont
#  telephon
#  priv
#  know
#
#
# Cluster 3:
#  democr
#  republ
#  congress
#  presid
#  thi
#  hav
#  ar
#  ther
#  work
#  country
#  think
#  wil
#  say
#  forward
#  som
#  act
#  mor
#  just
#  polit
#  idea
#
#
# Cluster 4:
#  campaign
#  ayesh
#  elect
#  trump
#  thi
#  presid
#  real
#  presidentelect
#  peopl
#  trail
#  wer
#  al
#  ther
#  surpr
#  think
#  rhet
#  wil
#  dur
#  diff
#  mr
#
#
# Cluster 5:
#  mr
#  earnest
#  okay
#  yeah
#  im
#  wel
#  margaret
#  ther
#  schultz
#  sur
#  wil
#  ar
#  point
#  thi
#  aw
#  lalit
#  rul
#  good
#  know
#  post
#
#
# Cluster 6:
#  admin
#  thi
#  doe
#  sanct
#  presid
#  incom
#  hav
#  trump
#  mor
#  think
#  said
#  north_korea
#  transit
#  kind
#  report
#  feel
#  new
#  the_white_hous
#  ther
#  josh
#
#
# Cluster 7:
#  ar
#  ther
#  thes
#  hav
#  som
#  peopl
#  thing
#  know
#  thi
#  presid
#  mor
#  mr
#  thos
#  think
#  stil
#  wher
#  oth
#  theyr
#  the_united_states
#  earnest
#
#
# Cluster 8:
#  end
#  ir
#  mayb
#  9999
#  chang
#  nat
#  huh
#  wel
#  earnest
#  bring
#  uran
#  jcpoa
#  mr
#  near
#  viol
#  sec
#  foot
#  nuclear
#  another_99_years
#  the_cabinet_ambassadors
#
#
# Cluster 9:
#  isil
#  fight
#  syr
#  coalit
#  op
#  iraq
#  thi
#  ar
#  hav
#  forc
#  ter
#  wer
#  turkey
#  ground
#  tak
#  raqq
#  attack
#  al
#  partn
#  campaign
#
#
# Cluster 10:
#  tomorrow
#  everybody
#  wel
#  thank
#  earnest
#  presid
#  going
#  speech
#  wil
#  mr
#  gaggl
#  som
#  plan
#  okay
#  draft
#  trip
#  process
#  giv
#  ther
#  josh
#
#
# Cluster 11:
#  going
#  say
#  thi
#  wer
#  ar
#  presid
#  just
#  ther
#  mean
#  elect
#  hav
#  im
#  said
#  think
#  tim
#  did
#  act
#  new
#  thing
#  wil
#
#
# Cluster 12:
#  hack
#  russ
#  thi
#  elect
#  dnc
#  leak
#  email
#  intellig
#  ther
#  inform
#  say
#  wer
#  int
#  the_white_hous
#  donald_trump
#  fact
#  act
#  hav
#  said
#  respons
#
#
# Cluster 13:
#  presid
#  obam
#  hav
#  hes
#  thi
#  country
#  opportun
#  wel
#  serv
#  work
#  wil
#  certain
#  mr
#  ther
#  peopl
#  earnest
#  admin
#  the_united_states
#  believ
#  al
#
#
# Cluster 14:
#  ir
#  nuclear
#  weapon
#  deal
#  intern
#  obtain
#  agr
#  prev
#  concern
#  sanct
#  thi
#  program
#  auth
#  hav
#  legisl
#  act
#  world
#  becaus
#  al
#  the_iran_sanctions_act
#
#
# Cluster 15:
#  policy
#  admin
#  presid
#  thi
#  hav
#  wil
#  pursu
#  incom
#  foreign
#  econom
#  wel
#  wer
#  tak
#  presidentelect
#  impl
#  certain
#  ar
#  consid
#  the_united_states
#  mor
#
#
# Cluster 16:
#  laught
#  earnest
#  mr
#  im
#  thank
#  okay
#  say
#  yeah
#  mayb
#  hav
#  going
#  yo
#  good
#  wel
#  presid
#  said
#  ev
#  know
#  ther
#  cov
#
#
# Cluster 17:
#  wil
#  meet
#  presid
#  the_white_hous
#  attend
#  mr
#  earnest
#  staff
#  ther
#  tel
#  hav
#  thursday
#  wel
#  brief
#  hop
#  thos
#  trip
#  thi
#  opportun
#  monday
#
#
# Cluster 18:
#  thank
#  josh
#  mr
#  everybody
#  earnest
#  apprecy
#  al
#  presid
#  yo
#  er
#  press
#  hav
#  sur
#  thi
#  wel
#  answ
#  guy
#  okay
#  bret
#  want
#
#
# Cluster 19:
#  heal
#  car
#  ins
#  the_affordable_care_act
#  republ
#  hav
#  rep
#  peopl
#  ar
#  access
#  protect
#  99_million
#  becaus
#  cost
#  company
#  mor
#  presid
#  grow
#  preex
#  condit
#
#
# Cluster 20:
#  let
#  il
#  mr
#  earnest
#  wel
#  know
#  thi
#  hav
#  quest
#  som
#  look
#  com
#  im
#  speak
#  just
#  going
#  earnest_ill
#  tim
#  tak
#  investig
#
#
# Cluster 21:
#  yo
#  say
#  talk
#  want
#  lik
#  thi
#  presid
#  hav
#  ther
#  al
#  mean
#  job
#  just
#  ar
#  way
#  som
#  wil
#  thank
#  going
#  mor
#
#
# Cluster 22:
#  the_united_states
#  sec
#  country
#  nat
#  econom
#  hav
#  protect
#  ar
#  work
#  thi
#  presid
#  al
#  som
#  world
#  oth
#  chin
#  sign
#  peopl
#  import
#  north_korea
#
#
# Cluster 23:
#  bil
#  sen
#  pass
#  justin
#  republ
#  sign
#  congress
#  presid
#  legisl
#  hav
#  support
#  thi
#  ar
#  ther
#  admin
#  fund
#  provid
#  vot
#  just
#  wil
#
#
# Cluster 24:
#  michel
#  follow
#  littl
#  aft
#  want
#  said
#  tim
#  nat
#  ear
#  presid
#  blood
#  fresh
#  exchang
#  eight_years
#  stag
#  bit
#  unacceiv
#  sec
#  bound
#  ourselv
#
#
# Cluster 25:
#  intellig
#  commun
#  inform
#  presid
#  assess
#  thi
#  report
#  hav
#  think
#  ther
#  stat
#  publ
#  elect
#  russ
#  direct
#  mr
#  earnest
#  som
#  bef
#  confid
#
#
# Cluster 26:
#  99
#  99_percent
#  rat
#  job
#  grow
#  presid
#  wag
#  sint
#  unemploy
#  hav
#  econom
#  ar
#  thi
#  record
#  wer
#  wev
#  ther
#  ov
#  cre
#  country
#
#
# Cluster 27:
#  mark
#  say
#  act
#  going
#  coupl
#  earnest
#  mr
#  cal
#  correct
#  ye
#  hack
#  pleas
#  continu
#  lik
#  policy
#  yo
#  sur
#  diff
#  way
#  asterisk
#
#
# Cluster 28:
#  giv
#  ahead
#  il
#  want
#  thi
#  inaud
#  im
#  tolus
#  lik
#  jord
#  ask
#  ther
#  josh
#  presid
#  com
#  did
#  read
#  nic
#  andrew
#  sort
#
#
# Cluster 29:
#  act
#  cyb
#  malicy
#  russ
#  elect
#  intellig
#  thi
#  wer
#  hav
#  ar
#  commun
#  govern
#  just
#  count
#  mr
#  interf
#  inform
#  oth
#  russia
#  eng
#
#
# Cluster 30:
#  resolv
#  israel
#  solv
#  settl
#  twost
#  act
#  wev
#  thi
#  viol
#  palestin
#  incit
#  hav
#  issu
#  condemn
#  effort
#  address
#  concern
#  stat
#  consist
#  trend
#
#
# Cluster 31:
#  think
#  presid
#  mr
#  thi
#  earnest
#  wel
#  ther
#  dont
#  hav
#  just
#  som
#  ar
#  thing
#  ind
#  lot
#  al
#  way
#  peopl
#  look
#  ev
#
#
# Cluster 32:
#  russ
#  diplom
#  syr
#  john
#  try
#  solv
#  wer
#  thi
#  ar
#  ther
#  the_united_states
#  act
#  aleppo
#  milit
#  situ
#  viol
#  hav
#  govern
#  wil
#  effort
#
#
# Cluster 33:
#  cub
#  migr
#  policy
#  wil
#  country
#  thi
#  ar
#  peopl
#  govern
#  travel
#  rel
#  the_united_states
#  hav
#  rep
#  the_cuban_adjustment_act
#  oth
#  hum
#  ther
#  thos
#  com
#
#
# Cluster 34:
#  decid
#  mad
#  mak
#  hav
#  presid
#  thi
#  wil
#  wer
#  ar
#  mr
#  ther
#  thos
#  independ
#  going
#  presidentelect
#  earnest
#  think
#  today
#  lead
#  ultim
#
#
# Cluster 35:
#  quest
#  yo
#  answ
#  ask
#  hav
#  mr
#  thi
#  want
#  start
#  im
#  tak
#  second
#  earnest
#  nic
#  ther
#  think
#  mor
#  good
#  look
#  wel
#
#
# Cluster 36:
#  kevin
#  ron
#  thank
#  start
#  stephany
#  opportun
#  earnest
#  apprecy
#  mr
#  want
#  polit
#  republ
#  com
#  im
#  going
#  wel
#  predict
#  washington
#  told
#  behavy
#
#
# Cluster 37:
#  hav
#  dont
#  mr
#  earnest
#  thi
#  som
#  wel
#  know
#  tim
#  presid
#  ther
#  look
#  report
#  new
#  seen
#  com
#  wil
#  today
#  upd
#  want
#
#
# Cluster 38:
#  respons
#  thi
#  ther
#  presid
#  hav
#  proport
#  publ
#  govern
#  ar
#  congress
#  som
#  wil
#  point
#  discuss
#  mr
#  the_united_states
#  im
#  earnest
#  think
#  includ
#
#
# Cluster 39:
#  right
#  presid
#  al
#  mr
#  earnest
#  ther
#  thi
#  ar
#  dont
#  someth
#  hap
#  lot
#  hum
#  com
#  hav
#  mor
#  ev
#  know
#  just
#  say

# %%
# does okay but others do better

# %% [markdown]
# ## LSI (gensim) + kmeans (3D plot)

# %%
corpus = matutils.Sparse2Corpus(vecs.transpose())
lsi = models.LsiModel(corpus, id2word=id2word, num_topics=300)
doc_vecs = lsi[corpus]
lsi_vecs = matutils.corpus2dense(doc_vecs, num_terms=300).transpose()
lsi_vecs = normalize(lsi_vecs)

# %%
cluster_num = 40
km = KMeans(n_clusters = cluster_num, random_state = 42)
km.fit(lsi_vecs)

# predict one cluster per document
predicted_cluster = km.predict(lsi_vecs)

# %%
df = pd.DataFrame(lsi_vecs[:,0:2], columns = ['first_feat', 'second_feat'])
df['cluster_c'] = predicted_cluster

sns.lmplot(x = 'first_feat', y='second_feat', hue = 'cluster_c', data = df, fit_reg = False)

# %%
df = pd.DataFrame(lsi_vecs[:,1:3], columns = ['second_feat', 'third_feat'])
df['cluster_c'] = predicted_cluster

sns.lmplot(x = 'second_feat', y='third_feat', hue = 'cluster_c', data = df, fit_reg = False)

# %%
df = pd.DataFrame(lsi_vecs[:,0], columns = ['first_feat'])
df['third_feat'] = lsi_vecs[:,2]
df['cluster_c'] = predicted_cluster

sns.lmplot(x = 'first_feat', y='third_feat', hue = 'cluster_c', data = df, fit_reg = False)

# %% [markdown]
# ## NMF + kmeans

# %%
nmf = NMF(n_components=300)
nmf_vecs = nmf.fit_transform(vecs)
nmf_vecs = Normalizer(copy=False).fit_transform(nmf_vecs)

# %%
# note: this doesn't deal with the cluster, just gets the words from nmf...
# first pass at what words go with each component
nmf_df = pd.DataFrame(nmf.components_.round(5),columns = tfidf.get_feature_names())

for i in range(20):
    print('Cluster number: ' + str(i))
    print(nmf_df.iloc[i,:].sort_values(ascending = False)[:15])
    print("")
# Out:
# Cluster number: 0
# presid                   1.99295
# vic                      0.07777
# obama                    0.03432
# visit                    0.02419
# bid                      0.02252
# candid                   0.01950
# spok                     0.01772
# whil                     0.01566
# ord                      0.01495
# remark                   0.01333
# counterpart              0.01226
# rac                      0.01079
# root                     0.00996
# donald_trump_laughter    0.00634
# travel                   0.00621
# Name: 0, dtype: float64
#
# Cluster number: 1
# earnest                   2.58637
# mr                        2.42144
# list                      0.03056
# alex                      0.01796
# bret                      0.01725
# saw                       0.01620
# indee                     0.01562
# earnest_happy_new_year    0.01480
# earnest_ron               0.01480
# huh                       0.01373
# earnest_john              0.01231
# richard                   0.01224
# tricky                    0.01150
# check                     0.01041
# refer                     0.01020
# Name: 1, dtype: float64
#
# Cluster number: 2
# thank      3.55246
# er         0.13149
# stop       0.06026
# jen        0.05161
# bret       0.04832
# behalf     0.04705
# sir        0.04688
# foreign    0.04631
# applaus    0.04523
# richard    0.04482
# wond       0.04338
# join       0.03987
# despit     0.03902
# mcgurk     0.03764
# spel       0.03676
# Name: 2, dtype: float64
#
# Cluster number: 3
# russ        1.51102
# effort      0.08676
# ukrain      0.07077
# ambassad    0.06787
# interf      0.06342
# influ       0.04591
# involv      0.04302
# tie         0.04148
# reta        0.03945
# conclud     0.03924
# ceasefir    0.03521
# behavy      0.03288
# g99         0.03152
# stockpil    0.03066
# putin       0.02878
# Name: 3, dtype: float64
#
# Cluster number: 4
# ar                                 1.83801
# liv                                0.05509
# refer                              0.01815
# restrict                           0.01276
# cap                                0.01100
# thousand                           0.01081
# property                           0.00944
# focus                              0.00905
# cur                                0.00902
# compound                           0.00893
# vary                               0.00859
# anonym                             0.00690
# prep                               0.00677
# deny                               0.00675
# the_popular_mobilization_forces    0.00633
# Name: 4, dtype: float64
#
# Cluster number: 5
# end                        2.68139
# 9999                       0.05136
# bring                      0.03322
# huh                        0.02461
# jcpoa                      0.02174
# uran                       0.02082
# viol                       0.02081
# near                       0.01942
# foot                       0.01578
# ready                      0.01451
# prom                       0.01392
# another_99_years           0.01352
# the_cabinet_ambassadors    0.01318
# reward                     0.01245
# over_a_year                0.01170
# Name: 5, dtype: float64
#
# Cluster number: 6
# quest       1.24279
# straight    0.03239
# handl       0.03081
# analyst     0.01852
# darl        0.01695
# mot         0.01637
# leg         0.01616
# fault       0.01441
# rhod        0.01438
# coupl       0.01404
# followup    0.01278
# focus       0.01253
# mr          0.01245
# dur         0.01188
# op          0.01162
# Name: 6, dtype: float64
#
# Cluster number: 7
# kevin         2.24277
# stephany      0.04326
# predict       0.01375
# expery        0.01333
# told          0.01280
# washington    0.01229
# behavy        0.01217
# israel        0.01176
# situ          0.01164
# wont          0.01133
# manufact      0.00841
# socy          0.00824
# ent           0.00756
# leg           0.00748
# root          0.00664
# Name: 7, dtype: float64
#
# Cluster number: 8
# okay            6.43546
# cr              0.15206
# barney          0.15003
# mcgurk          0.13160
# twic            0.07984
# comfort         0.07716
# inquiry         0.07346
# half_an_hour    0.07194
# late_night      0.06802
# oh              0.06328
# scheduled       0.06015
# yesterday       0.05814
# friday_night    0.05654
# holiday         0.04978
# regul           0.04322
# Name: 8, dtype: float64
#
# Cluster number: 9
# hav              2.93252
# seen             0.06738
# impact           0.03348
# francesc         0.01684
# youd             0.01384
# dog              0.01269
# confer           0.01063
# kept             0.00757
# oft              0.00754
# bought           0.00686
# rancho_mirage    0.00686
# gon              0.00680
# result           0.00679
# neg              0.00631
# heard            0.00563
# Name: 9, dtype: float64
#
# Cluster number: 10
# going             871.32545
# miss               46.94130
# rely               18.30422
# deep               12.22035
# resid              11.52547
# convint             7.72649
# div                 7.51224
# retak               7.07560
# recipy              6.76962
# requir              6.75100
# schultz_look        6.44132
# far                 6.30268
# consequ             5.84261
# built               5.62339
# the_oval_offic      5.42936
# Name: 10, dtype: float64
#
# Cluster number: 11
# ag          1.83575
# shutdown    0.30130
# intellig    0.25461
# individ     0.23914
# fed         0.21183
# opin        0.15714
# vary        0.14376
# employ      0.12979
# cabinet     0.10626
# plac        0.10073
# memo        0.09841
# guid        0.08960
# quick       0.08612
# check       0.08452
# exit        0.08283
# Name: 11, dtype: float64
#
# Cluster number: 12
# second           350.74079
# declass           48.44984
# min               31.46443
# prim              31.03493
# rhodes_jeh        22.09011
# hotlin            15.74373
# handl             13.99027
# donald_trumps     13.54374
# renz              12.77428
# earnest_first     12.51765
# cop               11.56256
# prec              10.23504
# equ               10.11999
# pak                9.56909
# sound              9.45770
# Name: 12, dtype: float64
#
# Cluster number: 13
# michel         2.17305
# blood          0.01285
# unacceiv       0.01228
# fresh          0.01190
# exchang        0.01137
# bound          0.01090
# ourselv        0.01033
# eight_years    0.01031
# stag           0.01028
# fre            0.00949
# depend         0.00908
# outsid         0.00904
# goe            0.00792
# cont           0.00781
# handl          0.00770
# Name: 13, dtype: float64
#
# Cluster number: 14
# wil             6.58672
# anticip         0.21954
# fut             0.18548
# swing           0.15969
# tamp            0.11129
# stand           0.10921
# thursday        0.10551
# ultim           0.09683
# determin        0.07285
# january_99th    0.06053
# choos           0.05894
# weekahead       0.05543
# next_week       0.05537
# asyl            0.05527
# predict         0.05318
# Name: 14, dtype: float64
#
# Cluster number: 15
# 99            2.55682
# 99_percent    0.17446
# domest        0.09179
# sint          0.09135
# iraq          0.08878
# manufact      0.08515
# pop           0.08182
# took          0.07829
# indian        0.07124
# cre           0.06348
# airstrik      0.06314
# settl         0.06212
# near          0.05922
# about_99      0.05693
# 99_million    0.05362
# Name: 15, dtype: float64
#
# Cluster number: 16
# im         16.05291
# wond        1.34734
# surpr       0.39102
# observ      0.35257
# cury        0.31124
# tempt       0.26776
# expert      0.26709
# consult     0.21764
# gam         0.19182
# def         0.17092
# ambigu      0.16814
# steep       0.15448
# repetit     0.13636
# priv        0.12635
# reluct      0.12588
# Name: 16, dtype: float64
#
# Cluster number: 17
# republ         2.76897
# idea           0.22664
# capitol_hil    0.15950
# strengthen     0.12733
# hous           0.11283
# unfortun       0.11052
# refus          0.09835
# block          0.09114
# flint          0.09019
# cybersec       0.08757
# replac         0.08593
# prom           0.08162
# congress       0.06125
# improv         0.05508
# washington     0.05447
# Name: 17, dtype: float64
#
# Cluster number: 18
# intellig    35.52881
# commun      33.58195
# assess       8.41112
# intern       1.53029
# method       1.44981
# doubt        1.43369
# integr       1.29651
# acc          1.14606
# conclud      1.04200
# evid         0.92289
# mot          0.92169
# unanim       0.86702
# pres         0.70660
# interf       0.69908
# unvarn       0.69747
# Name: 18, dtype: float64
#
# Cluster number: 19
# wel          2.19295
# goy          0.03592
# far          0.03096
# context      0.03008
# list         0.02664
# doll         0.02422
# guar         0.02317
# armtw        0.02186
# schedule     0.02145
# wait         0.01580
# pen          0.01409
# quit         0.01210
# trumpcare    0.01210
# text         0.01197
# sea          0.01155
# Name: 19, dtype: float64

# %%
cluster_num = 40
kmeans = KMeans(n_clusters=cluster_num)
km.fit(nmf_vecs)
predicted_cluster = km.predict(nmf_vecs)

# %%
df = pd.DataFrame(nmf_vecs[:,0:2], columns = ['first_feat', 'second_feat'])
df['cluster_c'] = predicted_cluster

sns.lmplot(x = 'first_feat', y='second_feat', hue = 'cluster_c', data = df, fit_reg = False, size = 7)

# %%
original_space_centroids = nmf.inverse_transform(km.cluster_centers_)
order_centroids = original_space_centroids.argsort()[:, ::-1]

# %%
for i in range(cluster_num):
    print("Cluster %d:" % i, end='')
    print(" ")
    for ind in order_centroids[i, :20]:
        print(' %s' % terms[ind], end='')  # print words in clusters
        print("")
    print(" ")
    print(" ")
print()
# Out:
# Cluster 0:
#  intellig
#  commun
#  bil
#  poss
#  think
#  someth
#  direct
#  youv
#  wev
#  doesnt
#  regard
#  sur
#  admin
#  releas
#  sign
#  meet
#  feel
#  respons
#  inform
#  diff
#
#
# Cluster 1:
#  aw
#  im
#  earnest
#  mr
#  spok
#  presid
#  hav
#  theyv
#  congress
#  wil
#  meet
#  hap
#  ask
#  view
#  rul
#  plac
#  endors
#  schedule
#  peopl
#  theyr
#
#
# Cluster 2:
#  transit
#  smoo
#  effect
#  team
#  ag
#  admin
#  ens
#  presid
#  commit
#  hav
#  ther
#  ar
#  thos
#  mr
#  presidentelect
#  incom
#  earnest
#  going
#  diff
#  wer
#
#
# Cluster 3:
#  hav
#  isil
#  thos
#  wil
#  going
#  think
#  ther
#  al
#  elect
#  dont
#  tak
#  today
#  mr
#  peopl
#  success
#  opportun
#  mak
#  fight
#  yo
#  becaus
#
#
# Cluster 4:
#  ye
#  earnest
#  mr
#  sir
#  anticip
#  sorry
#  youv
#  sign
#  mark
#  person
#  exact
#  okay
#  laught
#  wil
#  schultz
#  cas
#  certain
#  disput
#  yo
#  day
#
#
# Cluster 5:
#  respons
#  sam
#  presidentelect
#  publ
#  ther
#  discuss
#  the_united_states
#  intellig
#  proport
#  hav
#  presid
#  commun
#  think
#  ar
#  congress
#  govern
#  team
#  sec
#  wil
#  oth
#
#
# Cluster 6:
#  jord
#  famy
#  yo
#  friday
#  liv
#  presid
#  travel
#  obvy
#  thought
#  mr
#  earnest
#  aircraft
#  pray
#  peopl
#  obam
#  gre
#  country
#  fin
#  award
#  eith
#
#
# Cluster 7:
#  ar
#  ther
#  thes
#  going
#  thos
#  hav
#  peopl
#  thing
#  the_united_states
#  think
#  mr
#  al
#  country
#  som
#  earnest
#  govern
#  republ
#  oth
#  right
#  mor
#
#
# Cluster 8:
#  presid
#  ar
#  hav
#  mak
#  wil
#  act
#  thos
#  ther
#  law
#  obam
#  al
#  democr
#  sen
#  thes
#  mr
#  earnest
#  kind
#  tim
#  good
#  peopl
#
#
# Cluster 9:
#  russ
#  act
#  intellig
#  hav
#  commun
#  elect
#  cyb
#  malicy
#  som
#  diplom
#  syr
#  think
#  wer
#  stat
#  said
#  ther
#  effort
#  hack
#  oth
#  milit
#
#
# Cluster 10:
#  okay
#  earnest
#  mr
#  laught
#  gre
#  welcom
#  cr
#  barney
#  mcgurk
#  good
#  yo
#  answ
#  didnt
#  real
#  twic
#  oh
#  comfort
#  inquiry
#  half_an_hour
#  late_night
#
#
# Cluster 11:
#  kenne
#  approach
#  coupl
#  begin
#  immigr
#  describ
#  explain
#  reass
#  clos
#  touch
#  afterma
#  advoc
#  length
#  gon
#  pursu
#  org
#  team
#  met
#  transit
#  wisdom
#
#
# Cluster 12:
#  bil
#  ther
#  mark
#  sam
#  secret
#  inaud
#  olivy
#  think
#  elect
#  laught
#  ahead
#  second
#  yo
#  chris
#  nic
#  point
#  want
#  poss
#  wil
#  jeff
#
#
# Cluster 13:
#  thank
#  josh
#  everybody
#  mr
#  earnest
#  apprecy
#  laught
#  yo
#  al
#  er
#  sen
#  press
#  guy
#  work
#  sur
#  react
#  olivy
#  hav
#  want
#  nic
#
#
# Cluster 14:
#  quest
#  yo
#  presid
#  hav
#  mr
#  answ
#  earnest
#  ther
#  ar
#  think
#  im
#  start
#  wil
#  tak
#  say
#  som
#  al
#  going
#  want
#  com
#
#
# Cluster 15:
#  presid
#  obam
#  wil
#  hav
#  the_united_states
#  think
#  mr
#  did
#  going
#  abl
#  expect
#  earnest
#  presidentelect
#  hes
#  someth
#  ther
#  doe
#  lik
#  country
#  certain
#
#
# Cluster 16:
#  mor
#  hav
#  ther
#  right
#  wer
#  going
#  sorry
#  peopl
#  nee
#  think
#  wil
#  democr
#  lot
#  becaus
#  success
#  lik
#  elect
#  didnt
#  thing
#  mak
#
#
# Cluster 17:
#  just
#  hav
#  mr
#  earnest
#  wer
#  yo
#  ther
#  som
#  im
#  think
#  ar
#  going
#  mak
#  becaus
#  lik
#  thos
#  wel
#  way
#  sur
#  wil
#
#
# Cluster 18:
#  rep
#  the_affordable_care_act
#  republ
#  heal
#  tak
#  protect
#  democr
#  hav
#  ins
#  law
#  car
#  away
#  want
#  going
#  obamac
#  wil
#  replac
#  isil
#  99_million
#  work
#
#
# Cluster 19:
#  wel
#  earnest
#  mr
#  tomorrow
#  everybody
#  thank
#  think
#  hav
#  wil
#  thing
#  look
#  dont
#  al
#  certain
#  presid
#  work
#  tim
#  okay
#  strategy
#  thos
#
#
# Cluster 20:
#  just
#  presid
#  hav
#  think
#  obam
#  wil
#  al
#  policy
#  econom
#  mak
#  going
#  concern
#  country
#  mr
#  wel
#  peopl
#  ther
#  som
#  way
#  admin
#
#
# Cluster 21:
#  know
#  dont
#  mr
#  earnest
#  hav
#  ther
#  wer
#  hes
#  wel
#  som
#  hap
#  ar
#  peopl
#  think
#  im
#  wil
#  work
#  lik
#  laught
#  tim
#
#
# Cluster 22:
#  mad
#  presid
#  hav
#  decid
#  ar
#  progress
#  thos
#  think
#  the_united_states
#  country
#  ther
#  mr
#  earnest
#  wil
#  way
#  wer
#  wev
#  work
#  import
#  obam
#
#
# Cluster 23:
#  john
#  lay
#  coupl
#  enjoy
#  nam
#  ext
#  week
#  profound
#  garn
#  rhet
#  requir
#  ukrain
#  the_department_of_stat
#  simpl
#  sufficy
#  lgbt_americans
#  situ
#  the_national_security_council
#  world_series_championship
#  socy
#
#
# Cluster 24:
#  giv
#  il
#  hav
#  presid
#  wel
#  ther
#  sen
#  mr
#  peopl
#  ahead
#  yo
#  opportun
#  upd
#  earnest
#  wer
#  think
#  want
#  im
#  tak
#  numb
#
#
# Cluster 25:
#  99
#  job
#  grow
#  99_percent
#  rat
#  wag
#  presid
#  hav
#  econom
#  wer
#  unemploy
#  sint
#  record
#  ther
#  reduc
#  country
#  wev
#  obam
#  cre
#  strategy
#
#
# Cluster 26:
#  michel
#  said
#  follow
#  sec
#  nat
#  mat
#  gen
#  want
#  term
#  ment
#  tim
#  littl
#  convers
#  nee
#  adv
#  discuss
#  hav
#  bas
#  incom
#  wheth
#
#
# Cluster 27:
#  som
#  hav
#  presid
#  ther
#  thos
#  ar
#  think
#  mr
#  com
#  earnest
#  country
#  going
#  wil
#  yo
#  the_united_states
#  youv
#  forward
#  mak
#  wer
#  thes
#
#
# Cluster 28:
#  kevin
#  thank
#  want
#  earnest
#  mr
#  wel
#  apprecy
#  start
#  com
#  milit
#  lot
#  opportun
#  act
#  polit
#  stephany
#  id
#  tomorrow
#  republ
#  think
#  ref
#
#
# Cluster 29:
#  justin
#  mr
#  earnest
#  wel
#  guess
#  schultz
#  presidentelect
#  provid
#  chang
#  sur
#  point
#  report
#  wher
#  respons
#  republ
#  way
#  im
#  nat
#  team
#  ar
#
#
# Cluster 30:
#  look
#  mr
#  earnest
#  margaret
#  let
#  hav
#  dont
#  im
#  going
#  laught
#  mayb
#  wil
#  tak
#  think
#  everybody
#  answ
#  good
#  presidentelect
#  said
#  certain
#
#
# Cluster 31:
#  tolus
#  sorry
#  im
#  resist
#  coalit
#  past
#  yem
#  just_one
#  saudil
#  casual
#  undermin
#  strikes
#  heard
#  civil
#  simil
#  grav
#  assist
#  quick
#  the_paris_climate_agreement
#  ongo
#
#
# Cluster 32:
#  serv
#  presid
#  obam
#  think
#  wel
#  peopl
#  hav
#  the_united_states
#  country
#  believ
#  adv
#  wom
#  ov
#  somebody
#  wil
#  valu
#  secret
#  men
#  sen
#  ar
#
#
# Cluster 33:
#  end
#  did
#  obam
#  kind
#  admin
#  north_korea
#  nat
#  sec
#  tak
#  hav
#  mor
#  mayb
#  hap
#  laught
#  annount
#  mean
#  wel
#  leav
#  9999
#  chang
#
#
# Cluster 34:
#  second
#  report
#  class
#  declass
#  today
#  releas
#  brief
#  react
#  min
#  prim
#  presid
#  hav
#  seen
#  intellig
#  receiv
#  import
#  josh
#  publ
#  confirm
#  ar
#
#
# Cluster 35:
#  say
#  anyth
#  yo
#  mr
#  earnest
#  laught
#  presid
#  ther
#  oth
#  way
#  want
#  going
#  hav
#  im
#  admin
#  think
#  els
#  speech
#  try
#  thes
#
#
# Cluster 36:
#  earnest
#  mr
#  yeah
#  laught
#  wil
#  dont
#  im
#  sur
#  right
#  schultz
#  think
#  ther
#  point
#  hav
#  sorry
#  poss
#  correct
#  releas
#  apprecy
#  happy
#
#
# Cluster 37:
#  ron
#  list
#  dac
#  frust
#  debt
#  pot
#  took
#  fut
#  reason
#  margin
#  presidentelect_donald_trump
#  underestim
#  effort
#  begun
#  tweet
#  scen
#  beneficy
#  ess
#  earlier_in
#  record
#
#
# Cluster 38:
#  the_white_hous
#  attend
#  meet
#  wil
#  presid
#  doe
#  ask
#  hav
#  monday
#  thursday
#  react
#  cal
#  confirm
#  did
#  im
#  presidentelect
#  mr
#  today
#  sort
#  wond
#
#
# Cluster 39:
#  donald_trump
#  tweet
#  embold
#  talk
#  yesterday
#  presidentelect
#  said
#  nev
#  presid
#  pak
#  fact
#  vot
#  wont
#  say
#  thought
#  cal
#  lot
#  stat
#  ther
#  hack

# %% [markdown]
# ## switch to count vectorizer for LDA

# %%
stemmed_ents = lancaster_stem(underscore_entities(test))

# %%
cv = CountVectorizer(stop_words = 'english')
vecs = cv.fit_transform(stemmed_ents)

# %%
cv_df = pd.DataFrame(vecs.todense(), columns=cv.get_feature_names())
cv_df.shape
# Out:
# (5000, 6295)

# %%
terms = cv.get_feature_names()

# %%
terms
# Out:
# ['99',
#  '9999',
#  '9999_a',
#  '9999_p',
#  '99_99_million',
#  '99__and',
#  '99__fiscal_year_99',
#  '99__im',
#  '99__its',
#  '99_a_year',
#  '99_an_hour',
#  '99_and_99',
#  '99_billion',
#  '99_days',
#  '99_hours',
#  '99_hours_ago',
#  '99_in',
#  '99_in_the_dow',
#  '99_jobs',
#  '99_million',
#  '99_million_barrels',
#  '99_minutes',
#  '99_minutes_interview',
#  '99_months',
#  '99_or',
#  '99_or_99',
#  '99_or_99_years_ago',
#  '99_or_so',
#  '99_perc',
#  '99_percent',
#  '99_proisil',
#  '99_special_operations_forces',
#  '99_square_kilometers',
#  '99_straight_months',
#  '99_subpar_years',
#  '99_to',
#  '99_to_99',
#  '99_trillion',
#  '99_trillion_reduction',
#  '99_world_series_victory',
#  '99_years',
#  '99_years_ago',
#  '99_years_ago_this_week',
#  '99_years_ago_today',
#  '99_years_later',
#  '99_years_or_so',
#  '99character',
#  '99day',
#  '99foot',
#  '99kilometer',
#  '99month',
#  '99nd',
#  '99page',
#  '99plus_million',
#  '99pound',
#  '99s',
#  '99some_odd_years_or_so_ago',
#  '99st',
#  '99st_century',
#  '99th',
#  '_99',
#  '_brady_briefing_room',
#  '_bush',
#  '_but',
#  '_california',
#  '_central_command',
#  '_day',
#  '_eastern',
#  '_edgar_hoover',
#  '_general_assembly',
#  '_hwang',
#  '_ill',
#  '_kennedy',
#  '_navy',
#  '_obama',
#  '_petersburg',
#  '_president',
#  '_president_erdogan',
#  '_presidentelect_trump',
#  '_republican_leader_of_the_united_states_senate',
#  '_security_council',
#  '_security_council_resolution',
#  '_special_operations_command',
#  '_year',
#  'a99',
#  'a_99_percent',
#  'a_couple_days_ago',
#  'a_couple_minutes',
#  'a_couple_months_ago',
#  'a_couple_months_from_now',
#  'a_couple_of_other',
#  'a_couple_of_years',
#  'a_couple_weeks',
#  'a_day',
#  'a_day_later',
#  'a_defense_policy',
#  'a_department_of_homeland_security',
#  'a_few_days',
#  'a_few_days_ago',
#  'a_few_months',
#  'a_few_occasions',
#  'a_few_of_the',
#  'a_few_weeks_ago',
#  'a_few_years_ago',
#  'a_few_years_from_now',
#  'a_few_years_later',
#  'a_larger',
#  'a_lieutenant_general',
#  'a_long_period_of_time',
#  'a_month',
#  'a_month_ago',
#  'a_nobel_prize',
#  'a_republican_congress',
#  'a_season',
#  'a_thousand',
#  'a_u',
#  'a_week',
#  'a_week_ago',
#  'a_week_later',
#  'a_year',
#  'a_year_ago',
#  'a_year_of_growth',
#  'a_year_old',
#  'a_year_to_today',
#  'ab',
#  'abandon',
#  'abc',
#  'abc_news',
#  'abc_newswashington_post',
#  'abd',
#  'abd_albasit_aliraqi',
#  'abes_old',
#  'abet',
#  'abid',
#  'abl',
#  'aboard',
#  'abort',
#  'about_99',
#  'about_99_billion',
#  'about_99_days',
#  'about_99_miles',
#  'about_99_million',
#  'about_99_months_ago',
#  'about_99_perc',
#  'about_99_to_99',
#  'about__more',
#  'about_a_half_dozen',
#  'about_a_month_ago',
#  'about_a_thousand',
#  'about_a_week_ago',
#  'about_a_year',
#  'about_a_year_ago',
#  'about_a_year_later',
#  'about_eight',
#  'about_five_minutes',
#  'about_half',
#  'about_half_a_million',
#  'about_last_week',
#  'about_north_koreas',
#  'about_one',
#  'about_one_month_ago',
#  'about_six_months',
#  'about_six_months_ago',
#  'about_some_type',
#  'about_the_kind',
#  'about_three_days_ago',
#  'about_three_years',
#  'about_two',
#  'about_two_months',
#  'about_two_years_ago',
#  'abov',
#  'abroad',
#  'abs',
#  'absolv',
#  'absorb',
#  'abst',
#  'abstain',
#  'absurd',
#  'abu_bakr_baghdadi',
#  'abu_nabil',
#  'abus',
#  'abyss',
#  'ac',
#  'academ',
#  'acc',
#  'acceiv',
#  'accel',
#  'access',
#  'accid',
#  'acclaim',
#  'accompany',
#  'accompl',
#  'accord',
#  'account',
#  'accounts',
#  'accum',
#  'accus',
#  'achiev',
#  'acknowledg',
#  'aclu',
#  'acquir',
#  'acronym',
#  'act',
#  'activeduty',
#  'acut',
#  'ad',
#  'adam',
#  'adam_szubin',
#  'adapt',
#  'addict',
#  'addit',
#  'address',
#  'adequ',
#  'adh',
#  'adjud',
#  'adjust',
#  'admin',
#  'admir',
#  'admit',
#  'adn',
#  'adopt',
#  'adult',
#  'adv',
#  'advers',
#  'advert',
#  'advoc',
#  'aer',
#  'aetn',
#  'af',
#  'affair',
#  'affect',
#  'affin',
#  'affirm',
#  'afflict',
#  'afford',
#  'affordable_care_act',
#  'affy',
#  'afgh',
#  'afghanistanpak',
#  'afield',
#  'afo',
#  'afr',
#  'afraid',
#  'afric',
#  'african_americ',
#  'african_americans',
#  'aft',
#  'afteract',
#  'afterma',
#  'afternoon',
#  'aftertax',
#  'afterward',
#  'ag',
#  'age_99',
#  'age_99_or_so',
#  'age_of_99',
#  'agend',
#  'agenda',
#  'aggreg',
#  'aggress',
#  'ago',
#  'agr',
#  'agree',
#  'agreedupon',
#  'agricult',
#  'ahead',
#  'ahold',
#  'aid',
#  'aim',
#  'air',
#  'air_force_one',
#  'air_force_one_en_route_chicago',
#  'air_force_one_en_route_tampa',
#  'airbas',
#  'airborn',
#  'aircondit',
#  'aircraft',
#  'airlin',
#  'airpl',
#  'airspac',
#  'airstrik',
#  'aisl',
#  'aixtron',
#  'ak',
#  'al',
#  'al_gore',
#  'al_harvey',
#  'al_jazeera',
#  'al_nusra',
#  'al_qaeda',
#  'alabam',
#  'alarm',
#  'alask',
#  'alassad',
#  'albab',
#  'albaghdad',
#  'aleksey_belan',
#  'aleppo',
#  'aleppo_i',
#  'alert',
#  'alex',
#  'alex_platkin',
#  'alg',
#  'align',
#  'alik',
#  'all_african_american',
#  'all_eight_years',
#  'all_the',
#  'all_week',
#  'allam',
#  'allconsum',
#  'allday',
#  'alleg',
#  'allencompass',
#  'allevy',
#  'allnight',
#  'alloc',
#  'allow',
#  'alltim',
#  'allud',
#  'allvolunt',
#  'almost_99',
#  'almost_99_perc',
#  'almost_99_years',
#  'almost_any_hour',
#  'almost_eight_years',
#  'almost_exactly_eight',
#  'almost_seven_years',
#  'almost_six_years',
#  'almost_two_hours',
#  'alon',
#  'alt',
#  'alterc',
#  'altern',
#  'altitud',
#  'altogeth',
#  'alumin',
#  'alway',
#  'aly',
#  'amano',
#  'amass',
#  'amaz',
#  'amb',
#  'ambassad',
#  'ambassador_powers',
#  'ambassador_rice',
#  'ambigu',
#  'ambit',
#  'amend',
#  'americ',
#  'america',
#  'americangrown',
#  'americanmad',
#  'amid',
#  'ammunit',
#  'ampl',
#  'amy_sands',
#  'an_additional',
#  'an_hour',
#  'analog',
#  'analys',
#  'analysist',
#  'analyst',
#  'anb',
#  'anbar',
#  'anbar_province',
#  'and_lots',
#  'and_the',
#  'andre',
#  'andreas_when',
#  'andrew',
#  'ang',
#  'angela_merkel',
#  'angl',
#  'angry',
#  'angst',
#  'anim',
#  'anit',
#  'ank',
#  'ankar',
#  'annivers',
#  'annount',
#  'ano_po',
#  'anonym',
#  'anoth',
#  'another_99',
#  'another_99_years',
#  'another_month',
#  'another_six_months',
#  'answ',
#  'ant',
#  'antiaircraft',
#  'antiassad',
#  'antibal',
#  'anticip',
#  'antiisil',
#  'antiisrael',
#  'antilgbt',
#  'antimissil',
#  'antipoverty',
#  'antiruss',
#  'antisemit',
#  'antivir',
#  'antoinette_rangel',
#  'anxy',
#  'any_year',
#  'anybody',
#  'anym',
#  'anyon',
#  'anyth',
#  'anytim',
#  'anywh',
#  'ap',
#  'apart',
#  'apec',
#  'apolit',
#  'apolog',
#  'app',
#  'apparat',
#  'appear',
#  'appel',
#  'appetit',
#  'appl',
#  'applaud',
#  'applaus',
#  'application',
#  'apply',
#  'appoint',
#  'apport',
#  'appr',
#  'appra',
#  'apprecy',
#  'approach',
#  'appropry',
#  'approv',
#  'approximately_99_kilometers',
#  'april',
#  'april_99st',
#  'april_99th',
#  'april_of_last_year',
#  'april_say',
#  'apt',
#  'ar',
#  'arab',
#  'arabia',
#  'arabisrael',
#  'arch',
#  'architect',
#  'arct',
#  'ard',
#  'area',
#  'argentin',
#  'argu',
#  'ari_fleischer',
#  'arlington',
#  'arm',
#  'armtw',
#  'army',
#  'armynavy',
#  'aros',
#  'around_99_percent',
#  'arrang',
#  'array',
#  'ars',
#  'art',
#  'artic',
#  'as_long',
#  'as_many',
#  'as_many_of',
#  'as_much_a',
#  'as_much_as_possible',
#  'as_much_as_they',
#  'as_much_as_we_could',
#  'as_short_as_possible',
#  'ascrib',
#  'ash_carter',
#  'asid',
#  'ask',
#  'aspect',
#  'aspir',
#  'ass',
#  'assad',
#  'assang',
#  'assassin',
#  'assault',
#  'assembl',
#  'assert',
#  'assess',
#  'assessment_a_month',
#  'asset',
#  'assidu',
#  'assign',
#  'assist',
#  'assocy',
#  'assu',
#  'assum',
#  'asterisk',
#  'asyl',
#  'at_least',
#  'at_least_99',
#  'at_least_a_calculation',
#  'at_least_a_couple',
#  'at_least_a_generation',
#  'at_least_a_handful',
#  'at_least_a_thre',
#  'at_least_as',
#  'at_least_as_effective',
#  'at_least_four',
#  'at_least_on',
#  'at_least_one',
#  'at_least_three',
#  'at_least_two',
#  'athen',
#  'atl',
#  'atmosph',
#  'atom',
#  'atroc',
#  'atrocities',
#  'attach',
#  'attack',
#  'attempt',
#  'attend',
#  'attest',
#  'attitud',
#  'attorney',
#  'attract',
#  'attribut',
#  'audio',
#  'audiotap',
#  'audy',
#  'aug',
#  'august',
#  'august_99th',
#  'august_of_99_to_august_this_year',
#  'aust',
#  'austral',
#  'auth',
#  'authorit',
#  'auto',
#  'autom',
#  'automak',
#  'automobl',
#  'autonom',
#  'autowork',
#  'av',
#  'avail',
#  'avenu',
#  'avert',
#  'avoid',
#  'avuncul',
#  'avuncular_laught',
#  'aw',
#  'await',
#  'award',
#  'awardwin',
#  'awash',
#  'away',
#  'awesom',
#  'awkward',
#  'ax',
#  'axl',
#  'ayesh',
#  'bab',
#  'backandfor',
#  'backdrop',
#  'background',
#  'backlash',
#  'backlog',
#  'backoftheenvelop',
#  'backtrack',
#  'bad',
#  'bag',
#  'baghdad',
#  'baij',
#  'bail',
#  'baitandswitch',
#  'bal',
#  'balk',
#  'balloon',
#  'ballot',
#  'balt',
#  'baltim',
#  'ban',
#  'band',
#  'bandwid',
#  'bandy',
#  'bank',
#  'bankrupt',
#  'bankruptcy',
#  'bar',
#  'barack',
#  'barack_h',
#  'barack_hussein_obama',
#  'barack_obama',
#  'barb',
#  'bargain',
#  'barney',
#  'barry',
#  'bartend',
#  'bas',
#  'basebal',
#  'baseless',
#  'baselin',
#  'bash',
#  'bashar_alassad',
#  'bashar_alassads',
#  'bast',
#  'bat',
#  'batch',
#  'baton',
#  'battery',
#  'battl',
#  'battlefield',
#  'battleground',
#  'battleready',
#  'bear',
#  'bear_grylls',
#  'beard',
#  'beat',
#  'beauty',
#  'becam',
#  'becaus',
#  'beck_doreystein',
#  'becom',
#  'bed',
#  'bedevil',
#  'bedrock',
#  'bedroom',
#  'beefedup',
#  'bef',
#  'befal',
#  'beg',
#  'begin',
#  'begrudg',
#  'begun',
#  'behalf',
#  'behav',
#  'behavy',
#  'behest',
#  'behindthesc',
#  'bel',
#  'belg',
#  'believ',
#  'belong',
#  'ben',
#  'ben_rhodes',
#  'bench',
#  'benchmark',
#  'benef',
#  'beneficy',
#  'benefit',
#  'benghaz',
#  'ber',
#  'bergdahl',
#  'berlin',
#  'bernie_sanders',
#  'besid',
#  'besieg',
#  'best',
#  'bet',
#  'betray',
#  'between_99',
#  'between_99_and_the',
#  'between_april_and_october_to_allow_the_russians',
#  'between_now_and_january_99th',
#  'between_now_and_january_99th_other_than_to_confirm',
#  'between_now_and_th',
#  'between_now_and_the_end_of_his_administrat',
#  'between_now_and_the_end_of_the_administrat',
#  'between_now_and_wh',
#  'between_our_two_countries',
#  'between_representatives_of_the_united_states_government',
#  'between_the_two_countries',
#  'between_the_two_m',
#  'between_the_two_parties',
#  'between_two',
#  'bewild',
#  'bias',
#  'bic',
#  'bid',
#  'big',
#  'big_agenda',
#  'biggest',
#  'bil',
#  'bill_press',
#  'billboard',
#  'billions_of_dollar',
#  'billions_on_the_project',
#  'bin',
#  'bin_lad',
#  'bind',
#  'bipart',
#  'bir',
#  'birthplac',
#  'bisex',
#  'bit',
#  'bitepack',
#  'black',
#  'blackberry',
#  'blackenergy',
#  'blair_house',
#  'blam',
#  'blanket',
#  'blasphemy',
#  'blast',
#  'bless',
#  'blew',
#  'blind',
#  'blist',
#  'bloc',
#  'block',
#  'blood',
#  'bloodsh',
#  'bloodstream',
#  'bloody',
#  'bloomberg',
#  'blot',
#  'blow',
#  'blu',
#  'blue_ribbon',
#  'bluecoll',
#  'bluff',
#  'blunt',
#  'blust',
#  'bo',
#  'board',
#  'boatlift',
#  'bob',
#  'bob_corker',
#  'bob_dylan',
#  'bod',
#  'body',
#  'boe',
#  'bogachev',
#  'boil',
#  'boko_haram',
#  'bold',
#  'bolst',
#  'bomb',
#  'bon',
#  'bond',
#  'boo',
#  'book',
#  'bookend',
#  'boost',
#  'bord',
#  'born',
#  'borrow',
#  'boss',
#  'bottl',
#  'boubaker_alhakim',
#  'bought',
#  'bound',
#  'box',
#  'boy',
#  'boycot',
#  'brac',
#  'bracket',
#  'bradley_mannings',
#  'brag',
#  'brain',
#  'branch',
#  'brand',
#  'brandi_hoffine',
#  'brav',
#  'brea',
#  'breach',
#  'bread',
#  'break',
#  'breakdown',
#  'breakfast',
#  'breakthrough',
#  'breathtak',
#  'breezy',
#  'bren',
#  'bret',
#  'brett_mcgurk',
#  'brian_gabriel',
#  'brick',
#  'bridg',
#  'brief',
#  'bright',
#  'bring',
#  'brisk',
#  'brit',
#  'britain',
#  'broad',
#  'broadcast',
#  'broadest',
#  'brok',
#  'bronz',
#  'brothers_keeper_alliance',
#  'brought',
#  'brown',
#  'brows',
#  'brunt',
#  'brush',
#  'brussel',
#  'brut',
#  'bubbl',
#  'buck',
#  'bucket',
#  'buddy',
#  'budget',
#  'buff',
#  'buffet',
#  'build',
#  'built',
#  'builtin',
#  'builtup',
#  'bul',
#  'bulk',
#  'bullet',
#  'bum',
#  'bump',
#  'bumpy',
#  'bunch',
#  'bunk',
#  'bur',
#  'burd',
#  'burdensh',
#  'burea',
#  'bureau',
#  'bureaucr',
#  'burgeon',
#  'burn',
#  'burq',
#  'burrow',
#  'burwel',
#  'bury',
#  'bush',
#  'businesslik',
#  'busy',
#  'butb',
#  'button',
#  'buy',
#  'buzzfee',
#  'caa',
#  'cabinet',
#  'cabinetlevel',
#  'cabl',
#  'caitlin_young',
#  'cajol',
#  'cak',
#  'cal',
#  'calc',
#  'calend',
#  'californ',
#  'californiatosouthern_california',
#  'caliph',
#  'calm',
#  'cam',
#  'camaradery',
#  'cambridg',
#  'camer',
#  'camera',
#  'cameron',
#  'camp',
#  'campaign',
#  'canad',
#  'cancel',
#  'cancer_moonshot',
#  'candid',
#  'cannon',
#  'cap',
#  'capac',
#  'capit',
#  'capitol',
#  'capitol_hil',
#  'capt',
#  'car',
#  'carbon',
#  'card',
#  'carerel',
#  'carl_woog',
#  'carn',
#  'carney_laughter',
#  'carol',
#  'carry',
#  'carryov',
#  'cart',
#  'cas',
#  'casebycas',
#  'cash',
#  'cassidy',
#  'cast',
#  'castro',
#  'casual',
#  'catalog',
#  'catalys',
#  'catch',
#  'categ',
#  'cathy_mcmorris_rodgers',
#  'cauc',
#  'caucus',
#  'caught',
#  'caus',
#  'caut',
#  'cauty',
#  'cbo',
#  'cdc',
#  'cea',
#  'ceas',
#  'ceasefir',
#  'ced',
#  'celebr',
#  'celebrity_apprentice',
#  'cellphon',
#  'cem',
#  'cemetery',
#  'cens',
#  'cent',
#  'centcom',
#  'central_america',
#  'central_american',
#  'central_command',
#  'centrifug',
#  'centurieslong',
#  'century_cures_act',
#  'ceo',
#  'ceremony',
#  'cern',
#  'cert',
#  'certain',
#  'certainty',
#  'certitud',
#  'cess',
#  'ceter',
#  'cfi',
#  'chad',
#  'chaffetz',
#  'chain',
#  'chainofcommand',
#  'chair',
#  'chairm',
#  'chaka_fattah',
#  'challeng',
#  'chamb',
#  'champ',
#  'champagn',
#  'chancel',
#  'chancellor_merkel',
#  'chang',
#  'channel',
#  'chant',
#  'chao',
#  'chaot',
#  'chapt',
#  'char',
#  'charact',
#  'charg',
#  'chargescount',
#  'charles_schumer',
#  'charleston',
#  'charlot',
#  'chart',
#  'chat',
#  'che',
#  'cheap',
#  'check',
#  'checkup',
#  'chelsea_manning',
#  'chelsea_mannings',
#  'chem',
#  'cher',
#  'cheryl',
#  'chest',
#  'chew',
#  'chewedov',
#  'chicago',
#  'chief',
#  'child',
#  'childc',
#  'childless',
#  'childr',
#  'chin',
#  'china',
#  'chines',
#  'chip',
#  'chlorine',
#  'cho',
#  'chok',
#  'choos',
#  'choosy',
#  'chop',
#  'choppy',
#  'chos',
#  'chris',
#  'chris_fonzone',
#  'christians',
#  'christmas',
#  'christmas_to',
#  'chronicled',
#  'chronology',
#  'chuck_grassley',
#  'chuck_schumer',
#  'chuckl',
#  'chunk',
#  'church',
#  'cia',
#  ...]

# %% [markdown]
# ## LDA (gensim)

# %%
corpus = matutils.Sparse2Corpus(vecs.transpose())
lda = models.LdaModel(corpus=corpus, num_topics=40, id2word=id2word)
doc_vecs = lda[corpus]
lda_vecs = matutils.corpus2dense(doc_vecs, num_terms=300).transpose()
lda_vecs = normalize(lda_vecs)

# %%
# seems to repeat lots of common words
lda.print_topics(num_words = 50)
# Out:
# [(34,
#   '0.038*"sanct" + 0.030*"ther" + 0.022*"ar" + 0.015*"som" + 0.015*"thi" + 0.015*"yo" + 0.013*"going" + 0.013*"talk" + 0.013*"job" + 0.012*"know" + 0.011*"fund" + 0.011*"work" + 0.011*"mor" + 0.010*"thes" + 0.010*"admin" + 0.009*"concern" + 0.009*"try" + 0.009*"kind" + 0.009*"hav" + 0.008*"export" + 0.007*"want" + 0.007*"wer" + 0.007*"thing" + 0.007*"declass" + 0.007*"area" + 0.007*"presid" + 0.006*"bas" + 0.006*"commanderinchief" + 0.006*"wil" + 0.006*"way" + 0.006*"ir" + 0.006*"decid" + 0.006*"wher" + 0.006*"lik" + 0.006*"continu" + 0.006*"cr" + 0.006*"said" + 0.005*"impos" + 0.005*"numb" + 0.005*"district" + 0.005*"ess" + 0.005*"act" + 0.005*"mak" + 0.005*"auth" + 0.005*"tak" + 0.005*"just" + 0.005*"annount" + 0.004*"report" + 0.004*"mind" + 0.004*"oth"'),
#  (4,
#   '0.019*"cyb" + 0.018*"mat" + 0.017*"ther" + 0.016*"thi" + 0.016*"say" + 0.015*"act" + 0.015*"intrud" + 0.013*"hav" + 0.013*"intellig" + 0.012*"mr" + 0.012*"word" + 0.012*"commun" + 0.012*"resourc" + 0.011*"wer" + 0.010*"wel" + 0.010*"point" + 0.009*"rais" + 0.009*"affect" + 0.009*"flag" + 0.009*"think" + 0.008*"99" + 0.008*"ar" + 0.008*"just" + 0.007*"ask" + 0.007*"did" + 0.007*"quest" + 0.007*"malicy" + 0.007*"today" + 0.007*"poss" + 0.007*"hack" + 0.007*"target" + 0.007*"coupl" + 0.007*"clar" + 0.007*"plac" + 0.006*"earnest" + 0.006*"defens" + 0.006*"took" + 0.006*"eq" + 0.006*"lik" + 0.006*"want" + 0.006*"sort" + 0.006*"mor" + 0.006*"consid" + 0.006*"inform" + 0.005*"thank" + 0.005*"perhap" + 0.005*"octob" + 0.005*"diff" + 0.005*"tak" + 0.005*"russ"'),
#  (7,
#   '0.061*"presid" + 0.021*"sign" + 0.020*"wil" + 0.019*"thi" + 0.018*"speech" + 0.018*"going" + 0.013*"sort" + 0.012*"hav" + 0.012*"ther" + 0.011*"ess" + 0.011*"del" + 0.010*"ov" + 0.009*"mr" + 0.009*"talk" + 0.009*"said" + 0.008*"think" + 0.008*"99" + 0.008*"obam" + 0.008*"tuesday" + 0.007*"away" + 0.007*"rat" + 0.007*"know" + 0.007*"im" + 0.007*"okay" + 0.007*"tak" + 0.007*"ton" + 0.007*"hel" + 0.006*"hes" + 0.006*"standard" + 0.006*"trip" + 0.006*"prem" + 0.006*"air" + 0.006*"disagr" + 0.006*"mor" + 0.006*"admin" + 0.006*"want" + 0.005*"set" + 0.005*"remark" + 0.005*"last_year" + 0.005*"meet" + 0.005*"ev" + 0.005*"mayb" + 0.005*"tim" + 0.005*"attend" + 0.005*"earnest" + 0.005*"thank" + 0.004*"react" + 0.004*"ceremony" + 0.004*"giv" + 0.004*"cury"'),
#  (39,
#   '0.028*"wer" + 0.022*"thi" + 0.021*"act" + 0.021*"hav" + 0.019*"ther" + 0.018*"russ" + 0.014*"som" + 0.014*"ar" + 0.011*"hack" + 0.010*"presid" + 0.008*"dont" + 0.008*"know" + 0.008*"thos" + 0.008*"mor" + 0.007*"said" + 0.007*"quest" + 0.007*"thing" + 0.007*"oth" + 0.007*"talk" + 0.007*"govern" + 0.006*"war" + 0.006*"elect" + 0.006*"report" + 0.006*"say" + 0.006*"lead" + 0.005*"result" + 0.005*"new" + 0.005*"determin" + 0.005*"did" + 0.005*"behavy" + 0.005*"diplom" + 0.005*"think" + 0.005*"peopl" + 0.005*"sign" + 0.005*"campaign" + 0.005*"caus" + 0.005*"al" + 0.005*"respons" + 0.004*"tak" + 0.004*"wheth" + 0.004*"inconsist" + 0.004*"the_united_states" + 0.004*"intellig" + 0.004*"attack" + 0.004*"polit" + 0.004*"stat" + 0.004*"country" + 0.004*"bef" + 0.004*"want" + 0.004*"republ"'),
#  (19,
#   '0.027*"thi" + 0.023*"hav" + 0.019*"presid" + 0.018*"ar" + 0.016*"mr" + 0.014*"policy" + 0.014*"wil" + 0.012*"earnest" + 0.011*"thos" + 0.011*"wel" + 0.010*"ther" + 0.010*"hes" + 0.009*"respons" + 0.009*"country" + 0.007*"com" + 0.007*"admin" + 0.007*"iraq" + 0.007*"clear" + 0.006*"brief" + 0.006*"going" + 0.006*"mor" + 0.006*"just" + 0.006*"mad" + 0.006*"nat" + 0.006*"includ" + 0.006*"report" + 0.006*"sec" + 0.006*"wer" + 0.005*"publ" + 0.005*"al" + 0.005*"cub" + 0.005*"law" + 0.005*"the_united_states" + 0.005*"subst" + 0.005*"thing" + 0.005*"did" + 0.005*"talk" + 0.005*"constitut" + 0.004*"diff" + 0.004*"vary" + 0.004*"elect" + 0.004*"ov" + 0.004*"som" + 0.004*"counterter" + 0.004*"immigr" + 0.004*"peopl" + 0.004*"know" + 0.004*"mak" + 0.004*"think" + 0.004*"sign"'),
#  (32,
#   '0.030*"presid" + 0.025*"ther" + 0.021*"thi" + 0.016*"wil" + 0.015*"hav" + 0.014*"wer" + 0.013*"mor" + 0.012*"process" + 0.011*"think" + 0.011*"transit" + 0.010*"elect" + 0.010*"campaign" + 0.009*"govern" + 0.009*"attend" + 0.008*"ar" + 0.008*"smoo" + 0.008*"country" + 0.008*"meet" + 0.007*"just" + 0.007*"going" + 0.007*"mad" + 0.007*"al" + 0.007*"vot" + 0.007*"effect" + 0.007*"trail" + 0.006*"cast" + 0.006*"tamp" + 0.006*"admin" + 0.006*"the_white_hous" + 0.006*"say" + 0.006*"ens" + 0.006*"decid" + 0.006*"congress" + 0.006*"goal" + 0.005*"work" + 0.005*"thes" + 0.005*"evalu" + 0.005*"look" + 0.005*"sint" + 0.005*"tim" + 0.005*"act" + 0.005*"point" + 0.005*"overal" + 0.005*"plac" + 0.004*"milit" + 0.004*"doe" + 0.004*"outcom" + 0.004*"obam" + 0.004*"insight" + 0.004*"som"'),
#  (18,
#   '0.025*"thi" + 0.023*"presid" + 0.021*"hav" + 0.017*"ar" + 0.017*"99" + 0.011*"ther" + 0.011*"rel" + 0.010*"job" + 0.010*"country" + 0.009*"wer" + 0.009*"peopl" + 0.009*"al" + 0.008*"obam" + 0.008*"think" + 0.008*"som" + 0.007*"just" + 0.007*"mor" + 0.007*"econom" + 0.007*"point" + 0.007*"thos" + 0.007*"way" + 0.007*"admin" + 0.006*"concern" + 0.006*"sint" + 0.006*"mr" + 0.006*"tim" + 0.005*"press" + 0.005*"world" + 0.005*"bef" + 0.005*"oth" + 0.005*"grow" + 0.005*"the_united_states" + 0.005*"rat" + 0.005*"cre" + 0.005*"giv" + 0.005*"going" + 0.005*"humanit" + 0.005*"becaus" + 0.005*"say" + 0.005*"lik" + 0.005*"wev" + 0.004*"presidentelect" + 0.004*"seen" + 0.004*"diff" + 0.004*"benefit" + 0.004*"mak" + 0.004*"talk" + 0.004*"hum" + 0.004*"know" + 0.004*"act"'),
#  (16,
#   '0.023*"presid" + 0.019*"thi" + 0.015*"ar" + 0.013*"right" + 0.011*"ther" + 0.011*"influ" + 0.011*"enforc" + 0.011*"wil" + 0.010*"country" + 0.009*"valu" + 0.009*"ev" + 0.009*"mak" + 0.009*"al" + 0.009*"second" + 0.009*"hop" + 0.008*"north_korea" + 0.008*"just" + 0.008*"launch" + 0.008*"policy" + 0.007*"decad" + 0.007*"decid" + 0.007*"mov" + 0.007*"duty" + 0.007*"did" + 0.007*"ahead" + 0.007*"think" + 0.006*"admin" + 0.006*"doe" + 0.006*"som" + 0.006*"fut" + 0.006*"gain" + 0.006*"peac" + 0.006*"lead" + 0.006*"law" + 0.006*"inaug" + 0.006*"josh" + 0.006*"init" + 0.006*"record" + 0.006*"leav" + 0.006*"mor" + 0.006*"democr" + 0.006*"the_united_states" + 0.006*"tim" + 0.005*"perspect" + 0.005*"try" + 0.005*"ready" + 0.005*"understand" + 0.005*"ben" + 0.005*"long" + 0.005*"going"'),
#  (28,
#   '0.029*"presid" + 0.021*"im" + 0.019*"think" + 0.017*"cybersec" + 0.016*"real" + 0.015*"wond" + 0.014*"doe" + 0.014*"republ" + 0.014*"the_white_hous" + 0.012*"ther" + 0.012*"josh" + 0.010*"congress" + 0.010*"hav" + 0.010*"said" + 0.010*"anyth" + 0.008*"anybody" + 0.008*"react" + 0.008*"mor" + 0.008*"candid" + 0.008*"assum" + 0.008*"sen" + 0.007*"act" + 0.007*"quest" + 0.007*"prob" + 0.007*"this_morning" + 0.007*"99" + 0.006*"presidentelect_trump" + 0.006*"rac" + 0.006*"michig" + 0.006*"vot" + 0.006*"ar" + 0.006*"rescu" + 0.006*"al" + 0.006*"suggest" + 0.005*"mak" + 0.005*"way" + 0.005*"inform" + 0.005*"today" + 0.005*"wheth" + 0.005*"afterma" + 0.005*"presidentelect_donald_trump" + 0.005*"thos" + 0.005*"anoth" + 0.005*"wel" + 0.004*"talk" + 0.004*"thing" + 0.004*"wer" + 0.004*"govern" + 0.004*"say" + 0.004*"forward"'),
#  (21,
#   '0.029*"hav" + 0.023*"know" + 0.022*"mr" + 0.020*"som" + 0.019*"wel" + 0.017*"thi" + 0.017*"presid" + 0.017*"thos" + 0.015*"earnest" + 0.014*"dont" + 0.014*"presidentelect" + 0.012*"cal" + 0.011*"quest" + 0.011*"think" + 0.010*"phon" + 0.010*"support" + 0.010*"convers" + 0.009*"wil" + 0.008*"admin" + 0.008*"somebody" + 0.008*"believ" + 0.007*"lat" + 0.007*"meet" + 0.007*"let" + 0.007*"issu" + 0.007*"tak" + 0.007*"speak" + 0.007*"hand" + 0.007*"al" + 0.007*"com" + 0.007*"try" + 0.006*"team" + 0.006*"serv" + 0.006*"answ" + 0.006*"aft" + 0.006*"yo" + 0.006*"ar" + 0.006*"wer" + 0.006*"publ" + 0.005*"report" + 0.005*"direct" + 0.005*"just" + 0.005*"work" + 0.005*"im" + 0.005*"the_white_hous" + 0.005*"ther" + 0.005*"mak" + 0.004*"said" + 0.004*"99_billion" + 0.004*"sec"'),
#  (8,
#   '0.031*"resolv" + 0.021*"hav" + 0.019*"thi" + 0.015*"israel" + 0.014*"settl" + 0.014*"bring" + 0.014*"intern" + 0.013*"_security_council" + 0.012*"ter" + 0.012*"speak" + 0.011*"viol" + 0.011*"the_united_states" + 0.011*"act" + 0.010*"becaus" + 0.010*"wel" + 0.010*"gre" + 0.009*"regim" + 0.009*"leng" + 0.009*"just" + 0.008*"milit" + 0.007*"mr" + 0.007*"seen" + 0.007*"veto" + 0.007*"construct" + 0.007*"bal" + 0.007*"cont" + 0.007*"pleas" + 0.006*"solv" + 0.006*"folk" + 0.006*"ar" + 0.006*"reflect" + 0.006*"secret" + 0.006*"look" + 0.006*"concern" + 0.006*"commun" + 0.006*"plan" + 0.006*"incit" + 0.005*"ayesh" + 0.005*"exhibit" + 0.005*"try" + 0.005*"iv" + 0.005*"real" + 0.005*"touch" + 0.005*"want" + 0.005*"presid" + 0.005*"admin" + 0.005*"impos" + 0.005*"rhet" + 0.004*"earnest" + 0.004*"dont"'),
#  (36,
#   '0.088*"mr" + 0.058*"earnest" + 0.028*"hav" + 0.025*"schultz" + 0.025*"im" + 0.020*"laught" + 0.018*"doing" + 0.015*"dont" + 0.015*"ye" + 0.014*"ther" + 0.013*"anyth" + 0.013*"annount" + 0.012*"sur" + 0.011*"lik" + 0.011*"someth" + 0.010*"giv" + 0.009*"aw" + 0.009*"point" + 0.009*"okay" + 0.009*"look" + 0.008*"yo" + 0.008*"thi" + 0.008*"just" + 0.007*"spec" + 0.007*"presid" + 0.007*"som" + 0.007*"pattern" + 0.007*"know" + 0.007*"the_department_of_justic" + 0.007*"tim" + 0.006*"exact" + 0.006*"il" + 0.006*"consid" + 0.006*"good" + 0.006*"foc" + 0.005*"thank" + 0.005*"tak" + 0.005*"worry" + 0.005*"think" + 0.005*"reason" + 0.005*"elect" + 0.005*"noth" + 0.004*"admin" + 0.004*"guess" + 0.004*"did" + 0.004*"fed" + 0.004*"wev" + 0.004*"talk" + 0.004*"real" + 0.004*"wouldnt"'),
#  (0,
#   '0.063*"ar" + 0.027*"ther" + 0.021*"hav" + 0.016*"thi" + 0.014*"wer" + 0.013*"thos" + 0.010*"som" + 0.010*"mor" + 0.009*"thes" + 0.008*"oth" + 0.008*"peopl" + 0.008*"propos" + 0.007*"uniform" + 0.007*"congress" + 0.007*"extend" + 0.007*"mak" + 0.006*"revenu" + 0.006*"concern" + 0.006*"mr" + 0.006*"govern" + 0.006*"presid" + 0.006*"protect" + 0.006*"work" + 0.006*"stil" + 0.005*"earnest" + 0.005*"car" + 0.005*"kind" + 0.005*"wel" + 0.005*"al" + 0.005*"wom" + 0.005*"ev" + 0.005*"tak" + 0.005*"republ" + 0.004*"report" + 0.004*"cas" + 0.004*"lot" + 0.004*"readout" + 0.004*"transact" + 0.004*"sur" + 0.004*"ens" + 0.004*"plac" + 0.004*"memb" + 0.004*"theyr" + 0.004*"the_united_states" + 0.004*"includ" + 0.004*"worthy" + 0.004*"act" + 0.004*"wil" + 0.004*"extern" + 0.004*"mad"'),
#  (9,
#   '0.036*"hav" + 0.034*"presid" + 0.033*"meet" + 0.011*"doe" + 0.010*"al" + 0.010*"trump" + 0.010*"thank" + 0.010*"som" + 0.010*"transit" + 0.010*"doesnt" + 0.010*"just" + 0.009*"benefit" + 0.009*"com" + 0.009*"quest" + 0.009*"kil" + 0.009*"vic" + 0.009*"presidentelect" + 0.008*"rel" + 0.008*"wil" + 0.008*"wel" + 0.008*"south_korea" + 0.008*"the_white_hous" + 0.008*"philippin" + 0.007*"ag" + 0.007*"anyon" + 0.007*"optim" + 0.007*"admin" + 0.006*"commit" + 0.006*"thi" + 0.006*"team" + 0.006*"issu" + 0.006*"believ" + 0.006*"josh" + 0.006*"sometim" + 0.006*"sec" + 0.006*"ar" + 0.005*"help" + 0.005*"progress" + 0.005*"obvy" + 0.005*"work" + 0.005*"shutdown" + 0.005*"certain" + 0.005*"said" + 0.005*"the_state_department" + 0.005*"perspect" + 0.005*"way" + 0.005*"support" + 0.005*"invit" + 0.005*"door" + 0.005*"going"'),
#  (38,
#   '0.027*"thank" + 0.016*"solv" + 0.015*"thi" + 0.014*"new" + 0.013*"josh" + 0.013*"act" + 0.012*"wel" + 0.012*"refug" + 0.012*"policy" + 0.012*"presid" + 0.012*"gre" + 0.011*"yo" + 0.011*"someon" + 0.010*"quest" + 0.010*"thos" + 0.009*"und" + 0.009*"say" + 0.009*"result" + 0.009*"view" + 0.008*"kind" + 0.008*"eight_years" + 0.008*"foreign" + 0.008*"fact" + 0.008*"milit" + 0.007*"thing" + 0.007*"admin" + 0.007*"wil" + 0.007*"think" + 0.007*"just" + 0.007*"al" + 0.007*"hav" + 0.007*"giv" + 0.006*"mess" + 0.006*"discuss" + 0.006*"press" + 0.006*"way" + 0.006*"mak" + 0.006*"mr" + 0.006*"polit" + 0.006*"peopl" + 0.006*"going" + 0.005*"ar" + 0.005*"abov" + 0.005*"everybody" + 0.005*"posit" + 0.005*"wer" + 0.005*"country" + 0.005*"fut" + 0.005*"obvy" + 0.005*"stop"'),
#  (2,
#   '0.023*"presid" + 0.019*"hav" + 0.018*"congress" + 0.018*"thi" + 0.016*"ar" + 0.015*"wil" + 0.015*"mr" + 0.013*"sort" + 0.012*"ask" + 0.011*"interview" + 0.010*"wer" + 0.010*"ther" + 0.009*"discuss" + 0.009*"wel" + 0.008*"com" + 0.008*"earnest" + 0.007*"look" + 0.007*"process" + 0.007*"want" + 0.007*"mad" + 0.007*"execut" + 0.006*"act" + 0.006*"obam" + 0.006*"som" + 0.006*"russ" + 0.005*"memb" + 0.005*"admin" + 0.005*"im" + 0.005*"dont" + 0.005*"tak" + 0.005*"provid" + 0.005*"know" + 0.005*"hillary_clinton" + 0.005*"think" + 0.005*"donald_trump" + 0.005*"youv" + 0.005*"princip" + 0.005*"milit" + 0.005*"elect" + 0.005*"mor" + 0.005*"sensit" + 0.004*"weigh" + 0.004*"auth" + 0.004*"wher" + 0.004*"presidentelect" + 0.004*"outsid" + 0.004*"decid" + 0.004*"inst" + 0.004*"policy" + 0.004*"continu"'),
#  (15,
#   '0.021*"econom" + 0.020*"hav" + 0.014*"thi" + 0.013*"ar" + 0.013*"presid" + 0.013*"propos" + 0.011*"meas" + 0.010*"admin" + 0.009*"busy" + 0.008*"world" + 0.008*"going" + 0.008*"act" + 0.008*"wel" + 0.008*"agr" + 0.008*"partn" + 0.007*"viol" + 0.007*"mor" + 0.007*"think" + 0.007*"good" + 0.007*"som" + 0.007*"bar" + 0.006*"reduc" + 0.006*"deal" + 0.006*"bil" + 0.006*"work" + 0.006*"legisl" + 0.006*"und" + 0.006*"nee" + 0.006*"clos" + 0.006*"mak" + 0.005*"wat" + 0.005*"industry" + 0.005*"obam" + 0.005*"hard" + 0.005*"sustain" + 0.005*"mean" + 0.005*"thing" + 0.005*"country" + 0.005*"the_united_states" + 0.005*"produc" + 0.005*"largest" + 0.005*"thos" + 0.005*"grow" + 0.005*"term" + 0.005*"tak" + 0.005*"coop" + 0.005*"support" + 0.005*"say" + 0.004*"simpl" + 0.004*"forward"'),
#  (25,
#   '0.022*"presid" + 0.021*"ar" + 0.017*"ther" + 0.016*"hav" + 0.014*"country" + 0.013*"thi" + 0.011*"peopl" + 0.010*"admin" + 0.010*"vary" + 0.009*"team" + 0.009*"wer" + 0.008*"thing" + 0.008*"incom" + 0.008*"yo" + 0.008*"way" + 0.007*"kind" + 0.007*"act" + 0.007*"transit" + 0.007*"mad" + 0.007*"mak" + 0.007*"run" + 0.006*"tak" + 0.006*"abl" + 0.006*"understand" + 0.006*"gradu" + 0.006*"set" + 0.005*"wel" + 0.005*"certain" + 0.005*"ens" + 0.005*"prom" + 0.005*"theyr" + 0.005*"cam" + 0.005*"wil" + 0.005*"think" + 0.005*"right" + 0.005*"wev" + 0.005*"real" + 0.005*"mor" + 0.005*"look" + 0.005*"the_united_states" + 0.005*"mr" + 0.005*"tim" + 0.004*"stand" + 0.004*"obvy" + 0.004*"opportun" + 0.004*"al" + 0.004*"sign" + 0.004*"bad" + 0.004*"effect" + 0.004*"shak"'),
#  (1,
#   '0.026*"thi" + 0.024*"hav" + 0.021*"pass" + 0.015*"bil" + 0.014*"ther" + 0.014*"presid" + 0.013*"republ" + 0.013*"sign" + 0.011*"wer" + 0.011*"got" + 0.010*"congress" + 0.010*"budget" + 0.010*"ar" + 0.009*"im" + 0.009*"hes" + 0.009*"tim" + 0.009*"respons" + 0.009*"stil" + 0.008*"just" + 0.008*"prison" + 0.008*"wil" + 0.007*"detain" + 0.007*"want" + 0.006*"thing" + 0.006*"com" + 0.006*"ov" + 0.006*"guantanamo_bay" + 0.006*"review" + 0.005*"sur" + 0.005*"mak" + 0.005*"mr" + 0.005*"block" + 0.005*"send" + 0.005*"mor" + 0.005*"oth" + 0.004*"work" + 0.004*"wev" + 0.004*"unfortun" + 0.004*"someth" + 0.004*"bas" + 0.004*"left" + 0.004*"try" + 0.004*"ask" + 0.004*"watch" + 0.004*"law" + 0.004*"admin" + 0.004*"lot" + 0.004*"peopl" + 0.004*"presidentelect" + 0.004*"talk"'),
#  (17,
#   '0.027*"presid" + 0.026*"thi" + 0.022*"hav" + 0.019*"som" + 0.014*"wil" + 0.013*"wel" + 0.012*"act" + 0.011*"respons" + 0.011*"ther" + 0.011*"wev" + 0.010*"al" + 0.009*"thes" + 0.009*"know" + 0.009*"admin" + 0.009*"doe" + 0.009*"ar" + 0.009*"mr" + 0.009*"chang" + 0.008*"think" + 0.007*"tak" + 0.007*"presidentelect" + 0.007*"concern" + 0.006*"expect" + 0.006*"quest" + 0.006*"wer" + 0.006*"just" + 0.006*"trump" + 0.006*"nomin" + 0.006*"earnest" + 0.005*"the_united_states" + 0.005*"point" + 0.005*"difficult" + 0.005*"kind" + 0.005*"form" + 0.005*"obam" + 0.005*"mad" + 0.005*"peopl" + 0.005*"com" + 0.005*"posit" + 0.005*"tim" + 0.005*"work" + 0.005*"diplom" + 0.005*"clim" + 0.004*"situ" + 0.004*"sery" + 0.004*"congress" + 0.004*"clear" + 0.004*"continu" + 0.004*"memb" + 0.004*"met"')]

# %% [markdown]
# ## LDA (sklearn)

# %%
lda = LatentDirichletAllocation(n_topics=40)
lda_vecs = lda.fit_transform(vecs)
lda_vecs = Normalizer(copy=False).fit_transform(lda_vecs)
# Out:
# /Users/braeburn/anaconda/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:508: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)

# %%
# note: gets top words from lda

lda_df = pd.DataFrame(lda.components_.round(5),columns = terms)

for i in range(20):
    print('Component number: ' + str(i))
    print(lda_df.iloc[i,:].sort_values(ascending = False)[:15])
    print("")
# Out:
# Component number: 0
# a_few_days_ago       5.56987
# april                5.45642
# obsess               4.07483
# domin                3.01314
# percentil            2.98188
# sud                  2.70065
# japanes              2.43239
# screening            2.41344
# gossip               2.05776
# kabil                2.02589
# bloomberg            1.99652
# philip               1.27260
# appl                 1.21922
# our_department_of    1.21917
# the_past_year        1.21917
# Name: 0, dtype: float64
#
# Component number: 1
# nic                   28.10536
# caliph                13.62046
# baghdad                6.30139
# dav                    6.29788
# kenne                  5.58096
# bind                   3.76761
# happy_new_year         3.69661
# almost_eight_years     3.66465
# suppress               3.55395
# dimin                  3.29405
# audiotap               3.16298
# every_six_months       2.48412
# gallon                 2.27752
# tamperproof            2.27734
# schultz_hans           2.24461
# Name: 1, dtype: float64
#
# Component number: 2
# prim             61.90102
# min              58.88849
# market           40.16617
# react            34.93783
# chris             9.77458
# exit              7.33648
# netanyahu         6.61253
# lib               5.86053
# precid            5.80308
# jason             5.19416
# corrupt           4.24904
# ab                4.14774
# leader_pelosi     3.74972
# stev              3.52517
# singl             3.21538
# Name: 2, dtype: float64
#
# Component number: 3
# aft             116.40012
# start           109.03849
# spok             93.98797
# sint             77.44017
# judg             71.60239
# donald_trump     70.53537
# reluct           65.02681
# obam             58.70680
# avoid            47.66353
# presid           37.23783
# foc              34.97229
# perhap           34.89441
# attend           34.60648
# did              31.80462
# michel           30.34212
# Name: 3, dtype: float64
#
# Component number: 4
# greg               4.59323
# norway             3.71359
# wmd                3.66025
# fallout            2.89536
# opec               2.52003
# remaind            2.47587
# the_fiscal_year    2.46051
# last_one           2.41551
# schultz_jeff       2.41336
# barney             2.31039
# 99_subpar_years    1.99629
# norweg             1.25458
# forthcom           1.25457
# the_coming_year    1.25455
# schultz_olivier    1.21924
# Name: 4, dtype: float64
#
# Component number: 5
# bad           58.35349
# assist        53.90092
# sometim       47.14455
# sound         21.54198
# unprec        17.91084
# white_hous    16.45515
# light         15.46862
# mon           14.77300
# door          14.27257
# step          13.62433
# tariff        12.33553
# suff          10.38852
# interpret     10.35146
# tireless       9.88299
# the_years      8.55153
# Name: 5, dtype: float64
#
# Component number: 6
# germany                   11.17390
# margaret                  10.36866
# gardin                     9.72353
# ceter                      9.14689
# et                         9.14688
# goy                        8.11527
# chancel                    5.64075
# flaw                       5.58417
# casual                     5.51487
# macdill_air_force_base     3.59148
# berlin                     3.37516
# han                        2.90689
# chancellor_merkel          2.37832
# a_couple_of_years          2.31867
# merkel                     2.31169
# Name: 6, dtype: float64
#
# Component number: 7
# execut      88.18039
# presid      82.03539
# auth        74.42546
# analys      44.76487
# reflect     42.29552
# law         35.30306
# dat         33.90733
# obam        32.94384
# thes        32.40635
# institut    32.34024
# appoint     31.36050
# inaud       26.92887
# correct     23.70577
# root        22.64232
# branch      18.94005
# Name: 7, dtype: float64
#
# Component number: 8
# trump_tower                  4.78721
# relig                        4.77618
# god                          4.63134
# human_rights_day             3.35438
# rahm_emanuel                 3.10643
# bic                          2.44951
# the_situation_room           2.44942
# screening                    2.41348
# steward                      2.27752
# the_department_of_commerc    2.27751
# slick                        2.11717
# crack                        2.10421
# carol                        1.95793
# stretched                    1.55116
# nsc                          1.52674
# Name: 8, dtype: float64
#
# Component number: 9
# ir              135.52188
# intern          100.55407
# agr              98.32666
# nuclear          97.62202
# prev             87.44653
# weapon           55.89382
# deal             40.46085
# real             40.30901
# pleas            34.08068
# obtain           32.40827
# regim            32.11771
# north_korean     31.36371
# impos            29.31966
# bring            29.16620
# wasnt            28.74378
# Name: 9, dtype: float64
#
# Component number: 10
# lat        44.03462
# stay       39.06536
# sav        38.15462
# deficit    35.31352
# sent       25.14027
# cr         20.96605
# project    17.49447
# monday     13.58614
# anyon      12.95926
# jok        11.04609
# tied        9.73142
# celebr      9.51822
# kick        7.95840
# fisc        7.89307
# pdb         7.85194
# Name: 10, dtype: float64
#
# Component number: 11
# mr         733.16143
# presid     710.73720
# earnest    576.44068
# hav        477.51226
# wil        335.79163
# ther       293.30589
# 99         263.01189
# thank      247.56607
# know       221.10849
# tim        219.00872
# thi        210.33898
# dont       209.58712
# yo         192.65487
# meet       186.01018
# wel        185.79411
# Name: 11, dtype: float64
#
# Component number: 12
# north_korea                 72.89989
# civil                       60.05263
# threat                      58.06568
# defens                      53.62857
# cap                         52.06351
# the_department_of_defens    33.57653
# deploy                      32.66240
# protect                     29.51066
# south_korea                 26.05420
# construct                   25.06082
# missil                      24.44365
# milit                       23.99441
# reta                        18.50562
# jap                         18.20925
# coal                        17.15027
# Name: 12, dtype: float64
#
# Component number: 13
# republ                     261.94337
# congress                   167.34326
# democr                     160.10567
# rep                        134.48515
# going                       91.46268
# just                        89.45750
# ment                        78.52404
# youv                        74.65562
# the_affordable_care_act     72.89278
# mean                        62.29159
# law                         57.12304
# sid                         53.96204
# someon                      52.13752
# ide                         50.96858
# lik                         49.59406
# Name: 13, dtype: float64
#
# Component number: 14
# program          84.01588
# ahead            37.55156
# jar              19.15406
# ayesh            17.29782
# ben               9.50794
# stakehold         7.69241
# jc                3.98589
# vehic             3.75825
# early_october     2.96772
# forwardlook       2.55584
# welf              2.41433
# recalcit          2.26106
# schultz_so        2.21182
# wrestl            2.20481
# bottl             2.12443
# Name: 14, dtype: float64
#
# Component number: 15
# philippin                                 19.27542
# north_koreans                              3.76758
# scot                                       3.24086
# rosslyn                                    3.20995
# stumbl                                     2.41349
# french                                     2.26534
# albaghdad                                  2.11721
# gourm                                      2.11721
# belg                                       2.11718
# dprk                                       1.27249
# purple_hearts                              1.25458
# walter_reed                                1.25458
# the_purple_heart                           1.25455
# the_national_defense_authorization_act     1.21922
# schultz_kevin                              1.21921
# Name: 15, dtype: float64
#
# Component number: 16
# ineq                    10.01456
# robert                   6.55806
# slid                     5.93707
# tackl                    5.75587
# journey                  5.60560
# lowincom                 5.35346
# the_security_council     5.30687
# chapt                    4.66922
# grac                     4.66409
# sermon                   4.55053
# tour                     3.56652
# desp                     3.16838
# grand_mosque             2.11703
# congressman_prices       1.29075
# shaheen                  1.25457
# Name: 16, dtype: float64
#
# Component number: 17
# grow          117.44977
# youl           65.00027
# 99_percent     59.54857
# watch          53.82035
# recal          49.92531
# alway          46.85356
# read           43.84624
# opin           36.47613
# noth           29.00049
# fre            28.29147
# ov             27.40910
# endors         22.93664
# stock          22.21371
# took           20.42895
# thought        19.88082
# Name: 17, dtype: float64
#
# Component number: 18
# tre                  36.27784
# divid                20.03357
# addict                7.61302
# opioid                6.01865
# gulf                  5.74628
# net                   5.20901
# marijuan              4.87204
# overcom               4.77366
# hug                   4.34477
# fellow                4.32292
# display               4.26375
# unfair                4.15309
# the_next_99_years     3.78625
# isiss                 3.50405
# punit                 3.49411
# Name: 18, dtype: float64
#
# Component number: 19
# kevin                              42.80734
# felt                               25.83759
# lao                                20.57377
# the_hours                          20.53471
# jord                               11.68552
# mand                                9.37765
# ac                                  5.62476
# slaught                             5.02868
# assign                              5.01290
# isaac                               4.59879
# enthusiasm                          3.62806
# schultz_josh                        3.57307
# the_department_of_treasury          3.33050
# trib                                3.22698
# the_popular_mobilization_forces     3.16322
# Name: 19, dtype: float64

# %% [markdown]
# **things to try**
#
# dimensions
# 100 (x)
# 300 (x)
# 500 (x)
#
# dimensionality reduction
# SVD (x)
# NMF (x)
# LDA (x)
# word2vec?
#
# cluster algorithms:
# - kmeans (x)
# - dbscan (x)
# - hierarchical agglomerative clustering (x)
# - spectral (x)
#
# cluster numbers
# - 20 (x)
# - 40 (x)
# - 60 (x)
# - 80 (x)
#
# linkages
# - ward / average (x)

# %%
break
# Out:
#   File "<ipython-input-113-b20fcc2397e7>", line 1
#     break
#          ^
# SyntaxError: 'break' outside loop

# %% [markdown]
# ## misc.

# %% [markdown]
# ### lsi on documents and words...this should be an alternate way to get words out of clusters but isn't working...

# %%
# after having done tfidf...

# documents
corpus = matutils.Sparse2Corpus(vecs.transpose())
lsi = models.LsiModel(corpus, id2word=id2word, num_topics=300)
doc_vecs = lsi[corpus]
lsi_vecs = matutils.corpus2dense(doc_vecs, num_terms=300).transpose()

# words
vocabulary = list(tfidf.vocabulary_.keys())
vectorized_words = tfidf.transform(vocabulary)
word_corpus = matutils.Sparse2Corpus(vectorized_words.transpose())
word_vecs = lsi[word_corpus]
lsi_word_vecs = matutils.corpus2dense(word_vecs, num_terms = 300).transpose()

# %%
lsi_vecs.shape

# %%
lsi_word_vecs.shape

# %%
# remove first dimension
lsi_vecs = lsi_vecs[:,1:]
lsi_word_vecs = lsi_word_vecs[:,1:]

# normalize
normalized_lsi_vecs = normalize(lsi_vecs)
normalized_word_vecs = normalize(lsi_word_vecs)

# %%
km = KMeans(n_clusters = 20)
km.fit(normalized_lsi_vecs)
# predict one cluster per doc
predicted_cluster = km.predict(normalized_lsi_vecs)

# %%
neigh = NearestNeighbors(algorithm = 'brute', metric = 'cosine')
neigh.fit(normalized_word_vecs)
words_nearest_center = neigh.kneighbors(km.cluster_centers_)[1]

# %%
holder = []
for line in words_nearest_center:
    for num in line:
        holder.append(id2word[num])
nearest_words = np.asarray(holder)

pd.DataFrame(nearest_words.reshape([20, 5]))

# %%
df = pd.DataFrame(lsi_vecs[:,0:2], columns = ['first_feat', 'second_feat'])
df['cluster_c'] = predicted_cluster
sns.lmplot(x = 'first_feat', y='second_feat', hue = 'cluster_c', data = df, fit_reg = False, size = 10)

# %%
pd.Series(km.cluster_centers_[0]).sort_values(ascending=False)

# %%
list(km.predict(lsi_word_vecs))
